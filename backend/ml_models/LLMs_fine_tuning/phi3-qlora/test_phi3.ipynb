# %% [markdown]
# ## Fine-tuning Phi-3-mini-QLoRA
#
# Based on Phi-3Cookbook https://github.com/microsoft/Phi-3CookBook/blob/main/code/04.Finetuning/Phi-3-finetune-qlora-python.ipynb

# %% [markdown]
# Install required packages

# %%
# from IPython.display import clear_output
# !pip install -qqq --upgrade bitsandbytes transformers peft accelerate datasets trl flash_attn
# !pip install huggingface_hub
# !pip install python-dotenv
# !pip install wandb -qqq
# !pip install absl-py nltk rouge_score
# !pip list | grep transformers
# clear_output()

# %%
from IPython.display import clear_output
# !pip install peft==0.8.2
# !pip install bitsandbytes==0.42.0
# !pip install accelerate==0.26.1
# !pip install datasets==2.16.1
# !pip install GPUtil
# !pip install transformers==4.38.0
# !pip install huggingface-hub
# !pip install trl
# !pip install rouge_score
# !pip install -U sentence-transformers
clear_output()

# %%
# Get the scripts from remote source
# !git clone https://github.com/mlgomez0/Health_Therapist
# !mv Health_Therapist/backend/ml_models/modules/model_tester.py .
# !mv Health_Therapist/backend/ml_models/datasets/dataset.csv .
# !rm -rf Health_Therapist
# Out:
# Cloning into 'Health_Therapist'...
# remote: Enumerating objects: 646, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 646 (delta 11), reused 11 (delta 1), pack-reused 585
# Receiving objects: 100% (646/646), 22.44 MiB | 16.24 MiB/s, done.
# Resolving deltas: 100% (253/253), done.

# %% [markdown]
# # Import packages

# %%
import torch
from random import randrange
from peft import PeftModel
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import pandas as pd
from datasets import Dataset, DatasetDict

# %% [markdown]
# # Template Exploration

# %%
model_name = 'acorreal/phi3-mental-health'
adapter_name = 'acorreal/adapter-phi-3-mini-mental-health'
compute_dtype = torch.bfloat16

# %%
# %%time

# Load model
model = AutoModelForCausalLM.from_pretrained(model_name, trust_remote_code=True, torch_dtype=compute_dtype)
model = PeftModel.from_pretrained(model, adapter_name)
model = model.merge_and_unload()

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(adapter_name)

# Print model name
print("Model:", model.name_or_path)

# %%
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)

# %%
# Test the template
pipe.tokenizer.apply_chat_template([
    {
        "role": "user",
        "content": "Hello, I am stressed"}
    ],
    tokenize=False,
    add_generation_prompt=True
)

# %%
def predict(prompt: str) -> str:
    prompt = pipe.tokenizer.apply_chat_template([{"role": "user", "content": prompt}], tokenize=False, add_generation_prompt=True)
    outputs = pipe(prompt, max_new_tokens=256, do_sample=True, num_beams=1, temperature=0.3, top_k=50, top_p=0.95, max_time= 180)
    print(outputs)
    return outputs[0]['generated_text'][len(prompt):].strip()

# %%
# %%time
predict("i am going through some things with my feelings and myself i barely sleep and i do nothing but think about how i am worthless and how i should not be here i have never tried or contemplated suicide i have always wanted to fix my issues but i never get around to it how can i change my feeling of being worthless to everyone")

# %% [markdown]
# # Testing Generated Responses

# %% [markdown]
# ## microsoft/Phi-3-mini-4k-instruct

# %%
# load all model responses
import json
def load_responses(dataset, path, pipeline, tokenizer):
  counter = 0
  result = []
  for chat in dataset:
      gen_text = predict(chat['messages'][0]['content'], pipeline, tokenizer)
      input = chat['input']
      print(f"Got prediction: {counter}")
      result.append((input, gen_text))
      if counter % 10 == 0:
        with open(path, 'w') as f:
            print(f"Saving {len(result)} responses in file")
            json.dump(result, f)
      counter += 1
  return result

# %% [markdown]
# ### Preparing the dataset

# %%
df = pd.read_csv('dataset.csv')
df.columns = ['input', 'output']
df['instruction'] = "You are a mental health assistant. Your job is to provide emotional support, actively listen, and offer practical suggestions for well-being. Respond empathically and do not give specific medical advice or diagnoses. Always make sure the user feels heard and supported. If the user mentions suicidal thoughts, encourage them to seek professional help immediately. Here's the conversation so far:\n\n"
df.head()
# Out:
#                                                input  \
# 0  i am going through some things with my feeling...
# 1  i am going through some things with my feeling...
# 2  i am going through some things with my feeling...
# 3  i am going through some things with my feeling...
# 4  i am going through some things with my feeling...
#
#                                               output  \
# 0  if everyone thinks you are worthless then mayb...
# 1  hello and thank you for your question and seek...
# 2  first thing i would suggest is getting the sle...
# 3  therapy is essential for those that are feelin...
# 4  i first want to let you know that you are not ...
#
#                                          instruction
# 0  You are a mental health assistant. Your job is...
# 1  You are a mental health assistant. Your job is...
# 2  You are a mental health assistant. Your job is...
# 3  You are a mental health assistant. Your job is...
# 4  You are a mental health assistant. Your job is...

# %%
# Load the dataset
dataset = Dataset.from_pandas(df)
dataset
# Out:
# Dataset({
#     features: ['input', 'output', 'instruction'],
#     num_rows: 2747
# })

# %%
model_id = "microsoft/Phi-3-mini-4k-instruct"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)
tokenizer.padding_side = 'right' # to prevent warnings
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def create_message_column(row):
    messages = []
    user = {
        "content": f"{row['instruction']}\n Input: {row['input']}",
        "role": "user"
    }
    messages.append(user)
    assistant = {
        "content": f"{row['output']}",
        "role": "assistant"
    }
    messages.append(assistant)
    return {"messages": messages}

def format_dataset_chatml(row):
    return {"text": tokenizer.apply_chat_template(row["messages"], add_generation_prompt=False, tokenize=False)}

# %%
dataset_chatml = dataset.map(create_message_column)
dataset_chatml = dataset_chatml.map(format_dataset_chatml)
# Out:
# Map:   0%|          | 0/2747 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2747 [00:00<?, ? examples/s]

# %%
dataset_chatml
# Out:
# Dataset({
#     features: ['input', 'output', 'instruction', 'messages', 'text'],
#     num_rows: 2747
# })

# %%
dataset_chatml[0]
# Out:
# {'input': 'i am going through some things with my feelings and myself i barely sleep and i do nothing but think about how i am worthless and how i should not be here i have never tried or contemplated suicide i have always wanted to fix my issues but i never get around to it how can i change my feeling of being worthless to everyone',
#  'output': 'if everyone thinks you are worthless then maybe you need to find new people to hang out withseriously the social context in which a person lives is a big influence in selfesteemotherwise you can go round and round trying to understand why you are not worthless then go back to the same crowd and be knocked down againthere are many inspirational messages you can find in social media maybe read some of the ones which state that no person is worthless and that everyone has a good purpose to their lifealso since our culture is so saturated with the belief that if someone does not feel good about themselves that this is somehow terriblebad feelings are part of living they are the motivation to remove ourselves from situations and relationships which do us more harm than goodbad feelings do feel terrible your feeling of worthlessness may be good in the sense of motivating you to find out that you are much better than your feelings today',
#  'instruction': "You are a mental health assistant. Your job is to provide emotional support, actively listen, and offer practical suggestions for well-being. Respond empathically and do not give specific medical advice or diagnoses. Always make sure the user feels heard and supported. If the user mentions suicidal thoughts, encourage them to seek professional help immediately. Here's the conversation so far:\n\n",
#  'messages': [{'content': "You are a mental health assistant. Your job is to provide emotional support, actively listen, and offer practical suggestions for well-being. Respond empathically and do not give specific medical advice or diagnoses. Always make sure the user feels heard and supported. If the user mentions suicidal thoughts, encourage them to seek professional help immediately. Here's the conversation so far:\n\n\n Input: i am going through some things with my feelings and myself i barely sleep and i do nothing but think about how i am worthless and how i should not be here i have never tried or contemplated suicide i have always wanted to fix my issues but i never get around to it how can i change my feeling of being worthless to everyone",
#    'role': 'user'},
#   {'content': 'if everyone thinks you are worthless then maybe you need to find new people to hang out withseriously the social context in which a person lives is a big influence in selfesteemotherwise you can go round and round trying to understand why you are not worthless then go back to the same crowd and be knocked down againthere are many inspirational messages you can find in social media maybe read some of the ones which state that no person is worthless and that everyone has a good purpose to their lifealso since our culture is so saturated with the belief that if someone does not feel good about themselves that this is somehow terriblebad feelings are part of living they are the motivation to remove ourselves from situations and relationships which do us more harm than goodbad feelings do feel terrible your feeling of worthlessness may be good in the sense of motivating you to find out that you are much better than your feelings today',
#    'role': 'assistant'}],
#  'text': "<|user|>\nYou are a mental health assistant. Your job is to provide emotional support, actively listen, and offer practical suggestions for well-being. Respond empathically and do not give specific medical advice or diagnoses. Always make sure the user feels heard and supported. If the user mentions suicidal thoughts, encourage them to seek professional help immediately. Here's the conversation so far:\n\n\n Input: i am going through some things with my feelings and myself i barely sleep and i do nothing but think about how i am worthless and how i should not be here i have never tried or contemplated suicide i have always wanted to fix my issues but i never get around to it how can i change my feeling of being worthless to everyone<|end|>\n<|assistant|>\nif everyone thinks you are worthless then maybe you need to find new people to hang out withseriously the social context in which a person lives is a big influence in selfesteemotherwise you can go round and round trying to understand why you are not worthless then go back to the same crowd and be knocked down againthere are many inspirational messages you can find in social media maybe read some of the ones which state that no person is worthless and that everyone has a good purpose to their lifealso since our culture is so saturated with the belief that if someone does not feel good about themselves that this is somehow terriblebad feelings are part of living they are the motivation to remove ourselves from situations and relationships which do us more harm than goodbad feelings do feel terrible your feeling of worthlessness may be good in the sense of motivating you to find out that you are much better than your feelings today<|end|>\n<|endoftext|>"}

# %%
dataset_chatml = dataset_chatml.train_test_split(test_size=0.05, seed=1234)
dataset_chatml
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'output', 'instruction', 'messages', 'text'],
#         num_rows: 2609
#     })
#     test: Dataset({
#         features: ['input', 'output', 'instruction', 'messages', 'text'],
#         num_rows: 138
#     })
# })

# %% [markdown]
# ### Importing the models

# %%
original_model = AutoModelForCausalLM.from_pretrained(model_id, trust_remote_code=True)
# Out:
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4k-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.c1358f8a35e6d2af81890deffbbfa575b978c62f.modeling_phi3:`flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.c1358f8a35e6d2af81890deffbbfa575b978c62f.modeling_phi3:Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# model.safetensors.index.json:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]

# %%
finetuned_model_id = 'acorreal/phi3-mental-health'
finetuned_model = AutoModelForCausalLM.from_pretrained(finetuned_model_id, trust_remote_code=True)
# Out:
# config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors:   0%|          | 0.00/2.66G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]

# %%
original_pipeline = pipeline("text-generation", model=original_model, tokenizer=tokenizer)

# %%
finetuned_pipeline = pipeline("text-generation", model=finetuned_model, tokenizer=tokenizer)

# %%
def predict(prompt, pipeline, tokenizer):
    prompt = pipeline.tokenizer.apply_chat_template([{"role": "user", "content": prompt}], tokenize=False, add_generation_prompt=True)
    outputs = pipeline(prompt, max_new_tokens=256, do_sample=True, num_beams=1, temperature=0.3, top_k=50, top_p=0.95, max_time= 180)
    return outputs[0]['generated_text'][len(prompt):].strip()

# %%
predict(dataset_chatml['test'][0]['messages'][0]['content'], original_pipeline, tokenizer) #Original Model
# Out:
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.c1358f8a35e6d2af81890deffbbfa575b978c62f.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
# "I hear you, and it sounds like you're going through a really tough time. It's important to recognize that you're taking a brave step by acknowledging these patterns and seeking change. Building a secure relationship starts with understanding and respecting your own needs and boundaries. It's also crucial to work on self-esteem and independence, which can help you attract healthier relationships.\n\n\nHere are some practical steps you might consider:\n\n\n1. **Self-Reflection**: Take time to reflect on what you truly want in a relationship and why you're drawn to certain types of partners. Understanding your motivations can be the first step toward change.\n\n\n2. **Self-Care**: Make sure you're taking care of your physical and emotional well-being. Engage in activities that make you feel good about yourself and that you can enjoy on your own.\n\n\n3. **Boundaries**: Learn to set clear boundaries with others. This can help prevent you from being taken advantage of and teach others how to treat you.\n\n\n4. **Support System**: Surround yourself with supportive friends or family members who respect your boundaries"

# %%
predict(dataset_chatml['test'][0]['messages'][0]['content'], finetuned_pipeline, tokenizer) #Finetuned Model
# Out:
# "I hear you, and it's really brave of you to share these feelings. It sounds like you're searching for a sense of security and connection, which is completely understandable. Relationships can be complex, and it's not uncommon to feel stuck in patterns that aren't serving us.\n\n\nFirstly, it's important to recognize that you have the strength to change these patterns. It's a significant step to be aware of them. Perhaps we can explore some ways to build self-reliance and self-esteem, which can help you feel more comfortable being alone and doing things independently.\n\n\nOne approach could be to engage in activities that you enjoy and that make you feel good about yourself. This could be a hobby, exercise, or volunteering. These activities can help you grow and feel more confident in your own company.\n\n\nAlso, it might be helpful to reflect on what you're looking for in a relationship. What qualities do you value in a partner? Understanding these can guide you towards relationships that are more likely to meet your needs.\n\n\nRemember, it's okay to seek support from friends, family, or a counselor."

# %%
responses_fine_tuned_model = load_responses(dataset_chatml['test'], 'fine_tuned_model0.json', finetuned_pipeline, tokenizer)

# %%
responses_fine_tuned_model_train = load_responses(dataset_chatml['train'], 'fine_tuned_train_model0.json', finetuned_pipeline, tokenizer)
# Out:
# Got prediction: 0
# Saving 1 responses in file
# Got prediction: 1
# Got prediction: 2
# Got prediction: 3
# Got prediction: 4
# Got prediction: 5
# Got prediction: 6
# Got prediction: 7
# Got prediction: 8
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Got prediction: 9
# Got prediction: 10
# Saving 11 responses in file
# Got prediction: 11
# Got prediction: 12
# Got prediction: 13
# Got prediction: 14
# Got prediction: 15
# Got prediction: 16
# Got prediction: 17
# Got prediction: 18
# Got prediction: 19
# Got prediction: 20
# Saving 21 responses in file
# Got prediction: 21
# Got prediction: 22
# Got prediction: 23
# Got prediction: 24
# Got prediction: 25
# Got prediction: 26
# Got prediction: 27
# Got prediction: 28
# Got prediction: 29
# Got prediction: 30
# Saving 31 responses in file
# Got prediction: 31
# Got prediction: 32
# Got prediction: 33
# Got prediction: 34
# Got prediction: 35
# Got prediction: 36
# Got prediction: 37
# Got prediction: 38
# Got prediction: 39
# Got prediction: 40
# Saving 41 responses in file
# Got prediction: 41
# Got prediction: 42
# Got prediction: 43
# Got prediction: 44
# Got prediction: 45
# Got prediction: 46
# Got prediction: 47
# Got prediction: 48
# Got prediction: 49
# Got prediction: 50
# Saving 51 responses in file
# Got prediction: 51
# Got prediction: 52
# Got prediction: 53
# Got prediction: 54
# Got prediction: 55
# Got prediction: 56
# Got prediction: 57
# Got prediction: 58
# Got prediction: 59
# Got prediction: 60
# Saving 61 responses in file
# Got prediction: 61
# Got prediction: 62
# Got prediction: 63
# Got prediction: 64
# Got prediction: 65
# Got prediction: 66
# Got prediction: 67
# Got prediction: 68
# Got prediction: 69
# Got prediction: 70
# Saving 71 responses in file
# Got prediction: 71
# Got prediction: 72
# Got prediction: 73
# Got prediction: 74
# Got prediction: 75
# Got prediction: 76
# Got prediction: 77
# Got prediction: 78
# Got prediction: 79
# Got prediction: 80
# Saving 81 responses in file
# Got prediction: 81
# Got prediction: 82
# Got prediction: 83
# Got prediction: 84
# Got prediction: 85
# Got prediction: 86
# Got prediction: 87
# Got prediction: 88
# Got prediction: 89
# Got prediction: 90
# Saving 91 responses in file
# Got prediction: 91
# Got prediction: 92
# Got prediction: 93
# Got prediction: 94
# Got prediction: 95
# Got prediction: 96
# Got prediction: 97
# Got prediction: 98
# Got prediction: 99
# Got prediction: 100
# Saving 101 responses in file
# Got prediction: 101
# Got prediction: 102
# Got prediction: 103
# Got prediction: 104
# Got prediction: 105
# Got prediction: 106
# Got prediction: 107
# Got prediction: 108
# Got prediction: 109
# Got prediction: 110
# Saving 111 responses in file
# Got prediction: 111
# Got prediction: 112
# Got prediction: 113
# Got prediction: 114
# Got prediction: 115
# Got prediction: 116
# Got prediction: 117
# Got prediction: 118
# Got prediction: 119
# Got prediction: 120
# Saving 121 responses in file
# Got prediction: 121
# Got prediction: 122
# Got prediction: 123
# Got prediction: 124
# Got prediction: 125
# Got prediction: 126
# Got prediction: 127
# Got prediction: 128
# Got prediction: 129
# Got prediction: 130
# Saving 131 responses in file
# Got prediction: 131
# Got prediction: 132
# Got prediction: 133
# Got prediction: 134
# Got prediction: 135
# Got prediction: 136
# Got prediction: 137
# Got prediction: 138
# Got prediction: 139
# Got prediction: 140
# Saving 141 responses in file
# Got prediction: 141
# Got prediction: 142
# Got prediction: 143
# Got prediction: 144
# Got prediction: 145
# Got prediction: 146
# Got prediction: 147
# Got prediction: 148
# Got prediction: 149
# Got prediction: 150
# Saving 151 responses in file
# Got prediction: 151
# Got prediction: 152
# Got prediction: 153
# Got prediction: 154
# Got prediction: 155
# Got prediction: 156
# Got prediction: 157
# Got prediction: 158
# Got prediction: 159
# Got prediction: 160
# Saving 161 responses in file
# Got prediction: 161
# Got prediction: 162
# Got prediction: 163
# Got prediction: 164
# Got prediction: 165
# Got prediction: 166
# Got prediction: 167
# Got prediction: 168
# Got prediction: 169
# Got prediction: 170
# Saving 171 responses in file
# Got prediction: 171
# Got prediction: 172
# Got prediction: 173
# Got prediction: 174
# Got prediction: 175
# Got prediction: 176
# Got prediction: 177
# Got prediction: 178
# Got prediction: 179
# Got prediction: 180
# Saving 181 responses in file
# Got prediction: 181
# Got prediction: 182
# Got prediction: 183
# Got prediction: 184
# Got prediction: 185
# Got prediction: 186
# Got prediction: 187
# Got prediction: 188
# Got prediction: 189
# Got prediction: 190
# Saving 191 responses in file
# Got prediction: 191
# Got prediction: 192
# Got prediction: 193
# Got prediction: 194
# Got prediction: 195
# Got prediction: 196
# Got prediction: 197
# Got prediction: 198
# Got prediction: 199
# Got prediction: 200
# Saving 201 responses in file
# Got prediction: 201
# Got prediction: 202
# Got prediction: 203
# Got prediction: 204
# Got prediction: 205
# Got prediction: 206
# Got prediction: 207
# Got prediction: 208
# Got prediction: 209
# Got prediction: 210
# Saving 211 responses in file
# Got prediction: 211
# Got prediction: 212
# Got prediction: 213
# Got prediction: 214
# Got prediction: 215
# Got prediction: 216
# Got prediction: 217
# Got prediction: 218
# Got prediction: 219
# Got prediction: 220
# Saving 221 responses in file
# Got prediction: 221
# Got prediction: 222
# Got prediction: 223
# Got prediction: 224
# Got prediction: 225
# Got prediction: 226
# Got prediction: 227
# Got prediction: 228
# Got prediction: 229
# Got prediction: 230
# Saving 231 responses in file
# Got prediction: 231
# Got prediction: 232
# Got prediction: 233
# Got prediction: 234
# Got prediction: 235
# Got prediction: 236
# Got prediction: 237
# Got prediction: 238
# Got prediction: 239
# Got prediction: 240
# Saving 241 responses in file
# Got prediction: 241
# Got prediction: 242
# Got prediction: 243
# Got prediction: 244
# Got prediction: 245
# Got prediction: 246
# Got prediction: 247
# Got prediction: 248
# Got prediction: 249
# Got prediction: 250
# Saving 251 responses in file
# Got prediction: 251
# Got prediction: 252
# Got prediction: 253
# Got prediction: 254
# Got prediction: 255
# Got prediction: 256
# Got prediction: 257
# Got prediction: 258
# Got prediction: 259
# Got prediction: 260
# Saving 261 responses in file
# Got prediction: 261
# Got prediction: 262
# Got prediction: 263
# Got prediction: 264
# Got prediction: 265
# Got prediction: 266
# Got prediction: 267
# Got prediction: 268
# Got prediction: 269
# Got prediction: 270
# Saving 271 responses in file
# Got prediction: 271
# Got prediction: 272
# Got prediction: 273
# Got prediction: 274
# Got prediction: 275
# Got prediction: 276
# Got prediction: 277
# Got prediction: 278
# Got prediction: 279
# Got prediction: 280
# Saving 281 responses in file
# Got prediction: 281
# Got prediction: 282
# Got prediction: 283
# Got prediction: 284
# Got prediction: 285
# Got prediction: 286
# Got prediction: 287
# Got prediction: 288
# Got prediction: 289
# Got prediction: 290
# Saving 291 responses in file
# Got prediction: 291
# Got prediction: 292
# Got prediction: 293
# Got prediction: 294
# Got prediction: 295
# Got prediction: 296
# Got prediction: 297
# Got prediction: 298
# Got prediction: 299
# Got prediction: 300
# Saving 301 responses in file
# Got prediction: 301
# Got prediction: 302
# Got prediction: 303
# Got prediction: 304
# Got prediction: 305
# Got prediction: 306
# Got prediction: 307
# Got prediction: 308
# Got prediction: 309
# Got prediction: 310
# Saving 311 responses in file
# Got prediction: 311
# Got prediction: 312
# Got prediction: 313
# Got prediction: 314
# Got prediction: 315
# Got prediction: 316
# Got prediction: 317
# Got prediction: 318
# Got prediction: 319
# Got prediction: 320
# Saving 321 responses in file
# Got prediction: 321
# Got prediction: 322
# Got prediction: 323
# Got prediction: 324
# Got prediction: 325
# Got prediction: 326
# Got prediction: 327
# Got prediction: 328
# Got prediction: 329
# Got prediction: 330
# Saving 331 responses in file
# Got prediction: 331
# Got prediction: 332
# Got prediction: 333
# Got prediction: 334
# Got prediction: 335
# Got prediction: 336
# Got prediction: 337
# Got prediction: 338
# Got prediction: 339
# Got prediction: 340
# Saving 341 responses in file
# Got prediction: 341
# Got prediction: 342
# Got prediction: 343
# Got prediction: 344
# Got prediction: 345
# Got prediction: 346
# Got prediction: 347
# Got prediction: 348
# Got prediction: 349
# Got prediction: 350
# Saving 351 responses in file
# Got prediction: 351
# Got prediction: 352
# Got prediction: 353
# Got prediction: 354
# Got prediction: 355
# Got prediction: 356
# Got prediction: 357
# Got prediction: 358
# Got prediction: 359
# Got prediction: 360
# Saving 361 responses in file
# Got prediction: 361
# Got prediction: 362
# Got prediction: 363
# Got prediction: 364
# Got prediction: 365
# Got prediction: 366
# Got prediction: 367
# Got prediction: 368
# Got prediction: 369
# Got prediction: 370
# Saving 371 responses in file
# Got prediction: 371
# Got prediction: 372
# Got prediction: 373
# Got prediction: 374
# Got prediction: 375
# Got prediction: 376
# Got prediction: 377
# Got prediction: 378
# Got prediction: 379
# Got prediction: 380
# Saving 381 responses in file
# Got prediction: 381
# Got prediction: 382
# Got prediction: 383
# Got prediction: 384
# Got prediction: 385
# Got prediction: 386
# Got prediction: 387
# Got prediction: 388
# Got prediction: 389
# Got prediction: 390
# Saving 391 responses in file
# Got prediction: 391
# Got prediction: 392
# Got prediction: 393
# Got prediction: 394
# Got prediction: 395
# Got prediction: 396
# Got prediction: 397
# Got prediction: 398
# Got prediction: 399
# Got prediction: 400
# Saving 401 responses in file
# Got prediction: 401
# Got prediction: 402
# Got prediction: 403
# Got prediction: 404
# Got prediction: 405
# Got prediction: 406
# Got prediction: 407
# Got prediction: 408
# Got prediction: 409
# Got prediction: 410
# Saving 411 responses in file
# Got prediction: 411
# Got prediction: 412
# Got prediction: 413
# Got prediction: 414
# Got prediction: 415
# Got prediction: 416
# Got prediction: 417
# Got prediction: 418
# Got prediction: 419
# Got prediction: 420
# Saving 421 responses in file
# Got prediction: 421
# Got prediction: 422
# Got prediction: 423
# Got prediction: 424
# Got prediction: 425
# Got prediction: 426
# Got prediction: 427
# Got prediction: 428
# Got prediction: 429
# Got prediction: 430
# Saving 431 responses in file
# Got prediction: 431
# Got prediction: 432
# Got prediction: 433
# Got prediction: 434
# Got prediction: 435
# Got prediction: 436
# Got prediction: 437
# Got prediction: 438
# Got prediction: 439
# Got prediction: 440
# Saving 441 responses in file
# Got prediction: 441
# Got prediction: 442
# Got prediction: 443
# Got prediction: 444
# Got prediction: 445
# Got prediction: 446
# Got prediction: 447
# Got prediction: 448
# Got prediction: 449
# Got prediction: 450
# Saving 451 responses in file
# Got prediction: 451
# Got prediction: 452
# Got prediction: 453
# Got prediction: 454
# Got prediction: 455
# Got prediction: 456
# Got prediction: 457
# Got prediction: 458
# Got prediction: 459
# Got prediction: 460
# Saving 461 responses in file
# Got prediction: 461
# Got prediction: 462
# Got prediction: 463
# Got prediction: 464
# Got prediction: 465
# Got prediction: 466
# Got prediction: 467
# Got prediction: 468
# Got prediction: 469
# Got prediction: 470
# Saving 471 responses in file
# Got prediction: 471
# Got prediction: 472
# Got prediction: 473
# Got prediction: 474
# Got prediction: 475
# Got prediction: 476
# Got prediction: 477
# Got prediction: 478
# Got prediction: 479
# Got prediction: 480
# Saving 481 responses in file
# Got prediction: 481
# Got prediction: 482
# Got prediction: 483
# Got prediction: 484
# Got prediction: 485
# Got prediction: 486
# Got prediction: 487
# Got prediction: 488
# Got prediction: 489
# Got prediction: 490
# Saving 491 responses in file
# Got prediction: 491
# Got prediction: 492
# Got prediction: 493
# Got prediction: 494
# Got prediction: 495
# Got prediction: 496
# Got prediction: 497
# Got prediction: 498
# Got prediction: 499
# Got prediction: 500
# Saving 501 responses in file
# Got prediction: 501
# Got prediction: 502
# Got prediction: 503
# Got prediction: 504
# Got prediction: 505
# Got prediction: 506
# Got prediction: 507
# Got prediction: 508
# Got prediction: 509
# Got prediction: 510
# Saving 511 responses in file
# Got prediction: 511
# Got prediction: 512
# Got prediction: 513
# Got prediction: 514
# Got prediction: 515
# Got prediction: 516
# Got prediction: 517
# Got prediction: 518
# Got prediction: 519
# Got prediction: 520
# Saving 521 responses in file
# Got prediction: 521
# Got prediction: 522
# Got prediction: 523
# Got prediction: 524
# Got prediction: 525
# Got prediction: 526
# Got prediction: 527
# Got prediction: 528
# Got prediction: 529
# Got prediction: 530
# Saving 531 responses in file
# Got prediction: 531
# Got prediction: 532
# Got prediction: 533
# Got prediction: 534
# Got prediction: 535
# Got prediction: 536
# Got prediction: 537
# Got prediction: 538
# Got prediction: 539
# Got prediction: 540
# Saving 541 responses in file
# Got prediction: 541
# Got prediction: 542
# Got prediction: 543
# Got prediction: 544
# Got prediction: 545
# Got prediction: 546
# Got prediction: 547
# Got prediction: 548
# Got prediction: 549
# Got prediction: 550
# Saving 551 responses in file
# Got prediction: 551
# Got prediction: 552
# Got prediction: 553
# Got prediction: 554
# Got prediction: 555
# Got prediction: 556
# Got prediction: 557
# Got prediction: 558
# Got prediction: 559
# Got prediction: 560
# Saving 561 responses in file
# Got prediction: 561
# Got prediction: 562
# Got prediction: 563
# Got prediction: 564
# Got prediction: 565
# Got prediction: 566
# Got prediction: 567
# Got prediction: 568
# Got prediction: 569
# Got prediction: 570
# Saving 571 responses in file
# Got prediction: 571
# Got prediction: 572
# Got prediction: 573
# Got prediction: 574
# Got prediction: 575
# Got prediction: 576
# Got prediction: 577
# Got prediction: 578
# Got prediction: 579
# Got prediction: 580
# Saving 581 responses in file
# Got prediction: 581
# Got prediction: 582
# Got prediction: 583
# Got prediction: 584
# Got prediction: 585
# Got prediction: 586
# Got prediction: 587
# Got prediction: 588
# Got prediction: 589
# Got prediction: 590
# Saving 591 responses in file
# Got prediction: 591
# Got prediction: 592
# Got prediction: 593
# Got prediction: 594
# Got prediction: 595
# Got prediction: 596
# Got prediction: 597
# Got prediction: 598
# Got prediction: 599
# Got prediction: 600
# Saving 601 responses in file
# Got prediction: 601
# Got prediction: 602
# Got prediction: 603
# Got prediction: 604
# Got prediction: 605
# Got prediction: 606
# Got prediction: 607
# Got prediction: 608
# Got prediction: 609
# Got prediction: 610
# Saving 611 responses in file
# Got prediction: 611
# Got prediction: 612
# Got prediction: 613
# Got prediction: 614
# Got prediction: 615
# Got prediction: 616
# Got prediction: 617
# Got prediction: 618
# Got prediction: 619
# Got prediction: 620
# Saving 621 responses in file
# Got prediction: 621
# Got prediction: 622
# Got prediction: 623
# Got prediction: 624
# Got prediction: 625
# Got prediction: 626
# Got prediction: 627
# Got prediction: 628
# Got prediction: 629
# Got prediction: 630
# Saving 631 responses in file
# Got prediction: 631
# Got prediction: 632
# Got prediction: 633
# Got prediction: 634
# Got prediction: 635
# Got prediction: 636
# Got prediction: 637
# Got prediction: 638
# Got prediction: 639
# Got prediction: 640
# Saving 641 responses in file
# Got prediction: 641
# Got prediction: 642
# Got prediction: 643
# Got prediction: 644
# Got prediction: 645
# Got prediction: 646
# Got prediction: 647
# Got prediction: 648
# Got prediction: 649
# Got prediction: 650
# Saving 651 responses in file
# Got prediction: 651
# Got prediction: 652
# Got prediction: 653
# Got prediction: 654
# Got prediction: 655
# Got prediction: 656
# Got prediction: 657
# Got prediction: 658
# Got prediction: 659
# Got prediction: 660
# Saving 661 responses in file
# Got prediction: 661
# Got prediction: 662
# Got prediction: 663
# Got prediction: 664
# Got prediction: 665
# Got prediction: 666
# Got prediction: 667
# Got prediction: 668
# Got prediction: 669
# Got prediction: 670
# Saving 671 responses in file
# Got prediction: 671
# Got prediction: 672
# Got prediction: 673
# Got prediction: 674
# Got prediction: 675
# Got prediction: 676
# Got prediction: 677
# Got prediction: 678
# Got prediction: 679
# Got prediction: 680
# Saving 681 responses in file
# Got prediction: 681
# Got prediction: 682
# Got prediction: 683
# Got prediction: 684
# Got prediction: 685
# Got prediction: 686
# Got prediction: 687
# Got prediction: 688
# Got prediction: 689
# Got prediction: 690
# Saving 691 responses in file
# Got prediction: 691
# Got prediction: 692
# Got prediction: 693
# Got prediction: 694
# Got prediction: 695
# Got prediction: 696
# Got prediction: 697
# Got prediction: 698
# Got prediction: 699
# Got prediction: 700
# Saving 701 responses in file
# Got prediction: 701
# Got prediction: 702
# Got prediction: 703
# Got prediction: 704
# Got prediction: 705
# Got prediction: 706
# Got prediction: 707
# Got prediction: 708
# Got prediction: 709
# Got prediction: 710
# Saving 711 responses in file
# Got prediction: 711
# Got prediction: 712
# Got prediction: 713
# Got prediction: 714
# Got prediction: 715
# Got prediction: 716
# Got prediction: 717
# Got prediction: 718
# Got prediction: 719
# Got prediction: 720
# Saving 721 responses in file
# Got prediction: 721
# Got prediction: 722
# Got prediction: 723
# Got prediction: 724
# Got prediction: 725
# Got prediction: 726
# Got prediction: 727
# Got prediction: 728
# Got prediction: 729
# Got prediction: 730
# Saving 731 responses in file
# Got prediction: 731
# Got prediction: 732
# Got prediction: 733
# Got prediction: 734
# Got prediction: 735
# Got prediction: 736
# Got prediction: 737
# Got prediction: 738
# Got prediction: 739
# Got prediction: 740
# Saving 741 responses in file
# Got prediction: 741
# Got prediction: 742
# Got prediction: 743
# Got prediction: 744
# Got prediction: 745
# Got prediction: 746
# Got prediction: 747
# Got prediction: 748
# Got prediction: 749
# Got prediction: 750
# Saving 751 responses in file
# Got prediction: 751
# Got prediction: 752
# Got prediction: 753
# Got prediction: 754
# Got prediction: 755
# Got prediction: 756
# Got prediction: 757
# Got prediction: 758
# Got prediction: 759
# Got prediction: 760
# Saving 761 responses in file
# Got prediction: 761
# Got prediction: 762
# Got prediction: 763
# Got prediction: 764
# Got prediction: 765
# Got prediction: 766
# Got prediction: 767
# Got prediction: 768
# Got prediction: 769
# Got prediction: 770
# Saving 771 responses in file
# Got prediction: 771
# Got prediction: 772
# Got prediction: 773
# Got prediction: 774
# Got prediction: 775
# Got prediction: 776
# Got prediction: 777
# Got prediction: 778
# Got prediction: 779
# Got prediction: 780
# Saving 781 responses in file
# Got prediction: 781
# Got prediction: 782
# Got prediction: 783
# Got prediction: 784
# Got prediction: 785
# Got prediction: 786
# Got prediction: 787
# Got prediction: 788
# Got prediction: 789
# Got prediction: 790
# Saving 791 responses in file
# Got prediction: 791
# Got prediction: 792
# Got prediction: 793
# Got prediction: 794
# Got prediction: 795
# Got prediction: 796
# Got prediction: 797
# Got prediction: 798
# Got prediction: 799
# Got prediction: 800
# Saving 801 responses in file
# Got prediction: 801
# Got prediction: 802
# Got prediction: 803
# Got prediction: 804
# Got prediction: 805
# Got prediction: 806
# Got prediction: 807
# Got prediction: 808
# Got prediction: 809
# Got prediction: 810
# Saving 811 responses in file
# Got prediction: 811
# Got prediction: 812
# Got prediction: 813
# Got prediction: 814
# Got prediction: 815
# Got prediction: 816
# Got prediction: 817
# Got prediction: 818
# Got prediction: 819
# Got prediction: 820
# Saving 821 responses in file
# Got prediction: 821
# Got prediction: 822
# Got prediction: 823
# Got prediction: 824
# Got prediction: 825
# Got prediction: 826
# Got prediction: 827
# Got prediction: 828
# Got prediction: 829
# Got prediction: 830
# Saving 831 responses in file
# Got prediction: 831
# Got prediction: 832
# Got prediction: 833
# Got prediction: 834
# Got prediction: 835
# Got prediction: 836
# Got prediction: 837
# Got prediction: 838
# Got prediction: 839
# Got prediction: 840
# Saving 841 responses in file
# Got prediction: 841
# Got prediction: 842
# Got prediction: 843
# Got prediction: 844
# Got prediction: 845
# Got prediction: 846
# Got prediction: 847
# Got prediction: 848
# Got prediction: 849
# Got prediction: 850
# Saving 851 responses in file
# Got prediction: 851
# Got prediction: 852
# Got prediction: 853
# Got prediction: 854
# Got prediction: 855
# Got prediction: 856
# Got prediction: 857
# Got prediction: 858
# Got prediction: 859
# Got prediction: 860
# Saving 861 responses in file
# Got prediction: 861
# Got prediction: 862
# Got prediction: 863
# Got prediction: 864
# Got prediction: 865
# Got prediction: 866
# Got prediction: 867
# Got prediction: 868
# Got prediction: 869
# Got prediction: 870
# Saving 871 responses in file
# Got prediction: 871
# Got prediction: 872
# Got prediction: 873
# Got prediction: 874
# Got prediction: 875
# Got prediction: 876
# Got prediction: 877
# Got prediction: 878
# Got prediction: 879
# Got prediction: 880
# Saving 881 responses in file
# Got prediction: 881
# Got prediction: 882
# Got prediction: 883
# Got prediction: 884
# Got prediction: 885
# Got prediction: 886
# Got prediction: 887
# Got prediction: 888
# Got prediction: 889
# Got prediction: 890
# Saving 891 responses in file
# Got prediction: 891
# Got prediction: 892
# Got prediction: 893
# Got prediction: 894
# Got prediction: 895
# Got prediction: 896
# Got prediction: 897
# Got prediction: 898
# Got prediction: 899
# Got prediction: 900
# Saving 901 responses in file
# Got prediction: 901
# Got prediction: 902
# Got prediction: 903
# Got prediction: 904
# Got prediction: 905
# Got prediction: 906
# Got prediction: 907
# Got prediction: 908
# Got prediction: 909
# Got prediction: 910
# Saving 911 responses in file
# Got prediction: 911
# Got prediction: 912
# Got prediction: 913
# Got prediction: 914
# Got prediction: 915
# Got prediction: 916
# Got prediction: 917
# Got prediction: 918
# Got prediction: 919
# Got prediction: 920
# Saving 921 responses in file
# Got prediction: 921
# Got prediction: 922
# Got prediction: 923
# Got prediction: 924
# Got prediction: 925
# Got prediction: 926
# Got prediction: 927
# Got prediction: 928
# Got prediction: 929
# Got prediction: 930
# Saving 931 responses in file
# Got prediction: 931
# Got prediction: 932
# Got prediction: 933
# Got prediction: 934
# Got prediction: 935
# Got prediction: 936
# Got prediction: 937
# Got prediction: 938
# Got prediction: 939
# Got prediction: 940
# Saving 941 responses in file
# Got prediction: 941
# Got prediction: 942
# Got prediction: 943
# Got prediction: 944
# Got prediction: 945
# Got prediction: 946
# Got prediction: 947
# Got prediction: 948
# Got prediction: 949
# Got prediction: 950
# Saving 951 responses in file
# Got prediction: 951
# Got prediction: 952
# Got prediction: 953
# Got prediction: 954
# Got prediction: 955
# Got prediction: 956
# Got prediction: 957
# Got prediction: 958
# Got prediction: 959
# Got prediction: 960
# Saving 961 responses in file
# Got prediction: 961
# Got prediction: 962
# Got prediction: 963
# Got prediction: 964
# Got prediction: 965
# Got prediction: 966
# Got prediction: 967
# Got prediction: 968
# Got prediction: 969
# Got prediction: 970
# Saving 971 responses in file
# Got prediction: 971
# Got prediction: 972
# Got prediction: 973
# Got prediction: 974
# Got prediction: 975
# Got prediction: 976
# Got prediction: 977
# Got prediction: 978
# Got prediction: 979
# Got prediction: 980
# Saving 981 responses in file
# Got prediction: 981
# Got prediction: 982
# Got prediction: 983
# Got prediction: 984
# Got prediction: 985
# Got prediction: 986
# Got prediction: 987
# Got prediction: 988
# Got prediction: 989
# Got prediction: 990
# Saving 991 responses in file
# Got prediction: 991
# Got prediction: 992
# Got prediction: 993
# Got prediction: 994
# Got prediction: 995
# Got prediction: 996
# Got prediction: 997
# Got prediction: 998
# Got prediction: 999
# Got prediction: 1000
# Saving 1001 responses in file
# Got prediction: 1001
# Got prediction: 1002
# Got prediction: 1003
# Got prediction: 1004
# Got prediction: 1005
# Got prediction: 1006
# Got prediction: 1007
# Got prediction: 1008
# Got prediction: 1009
# Got prediction: 1010
# Saving 1011 responses in file
# Got prediction: 1011
# Got prediction: 1012
# Got prediction: 1013
# Got prediction: 1014
# Got prediction: 1015
# Got prediction: 1016
# Got prediction: 1017
# Got prediction: 1018
# Got prediction: 1019
# Got prediction: 1020
# Saving 1021 responses in file
# Got prediction: 1021
# Got prediction: 1022
# Got prediction: 1023
# Got prediction: 1024
# Got prediction: 1025
# Got prediction: 1026
# Got prediction: 1027
# Got prediction: 1028
# Got prediction: 1029
# Got prediction: 1030
# Saving 1031 responses in file
# Got prediction: 1031
# Got prediction: 1032
# Got prediction: 1033
# Got prediction: 1034
# Got prediction: 1035
# Got prediction: 1036
# Got prediction: 1037
# Got prediction: 1038
# Got prediction: 1039
# Got prediction: 1040
# Saving 1041 responses in file
# Got prediction: 1041
# Got prediction: 1042
# Got prediction: 1043
# Got prediction: 1044
# Got prediction: 1045
# Got prediction: 1046
# Got prediction: 1047
# Got prediction: 1048
# Got prediction: 1049
# Got prediction: 1050
# Saving 1051 responses in file
# Got prediction: 1051
# Got prediction: 1052
# Got prediction: 1053
# Got prediction: 1054
# Got prediction: 1055
# Got prediction: 1056
# Got prediction: 1057
# Got prediction: 1058
# Got prediction: 1059
# Got prediction: 1060
# Saving 1061 responses in file
# Got prediction: 1061
# Got prediction: 1062
# Got prediction: 1063
# Got prediction: 1064
# Got prediction: 1065
# Got prediction: 1066
# Got prediction: 1067
# Got prediction: 1068
# Got prediction: 1069
# Got prediction: 1070
# Saving 1071 responses in file
# Got prediction: 1071
# Got prediction: 1072
# Got prediction: 1073
# Got prediction: 1074
# Got prediction: 1075
# Got prediction: 1076
# Got prediction: 1077
# Got prediction: 1078
# Got prediction: 1079
# Got prediction: 1080
# Saving 1081 responses in file
# Got prediction: 1081
# Got prediction: 1082
# Got prediction: 1083
# Got prediction: 1084
# Got prediction: 1085
# Got prediction: 1086
# Got prediction: 1087
# Got prediction: 1088
# Got prediction: 1089
# Got prediction: 1090
# Saving 1091 responses in file
# Got prediction: 1091
# Got prediction: 1092
# Got prediction: 1093
# Got prediction: 1094
# Got prediction: 1095
# Got prediction: 1096
# Got prediction: 1097
# Got prediction: 1098
# Got prediction: 1099
# Got prediction: 1100
# Saving 1101 responses in file
# Got prediction: 1101
# Got prediction: 1102
# Got prediction: 1103
# Got prediction: 1104
# Got prediction: 1105
# Got prediction: 1106
# Got prediction: 1107
# Got prediction: 1108
# Got prediction: 1109
# Got prediction: 1110
# Saving 1111 responses in file
# Got prediction: 1111
# Got prediction: 1112
# Got prediction: 1113
# Got prediction: 1114
# Got prediction: 1115
# Got prediction: 1116
# Got prediction: 1117
# Got prediction: 1118
# Got prediction: 1119
# Got prediction: 1120
# Saving 1121 responses in file
# Got prediction: 1121
# Got prediction: 1122
# Got prediction: 1123
# Got prediction: 1124
# Got prediction: 1125
# Got prediction: 1126
# Got prediction: 1127
# Got prediction: 1128
# Got prediction: 1129
# Got prediction: 1130
# Saving 1131 responses in file
# Got prediction: 1131
# Got prediction: 1132
# Got prediction: 1133
# Got prediction: 1134
# Got prediction: 1135
# Got prediction: 1136
# Got prediction: 1137
# Got prediction: 1138
# Got prediction: 1139
# Got prediction: 1140
# Saving 1141 responses in file
# Got prediction: 1141
# Got prediction: 1142
# Got prediction: 1143
# Got prediction: 1144
# Got prediction: 1145
# Got prediction: 1146
# Got prediction: 1147
# Got prediction: 1148
# Got prediction: 1149
# Got prediction: 1150
# Saving 1151 responses in file
# Got prediction: 1151
# Got prediction: 1152
# Got prediction: 1153
# Got prediction: 1154
# Got prediction: 1155
# Got prediction: 1156
# Got prediction: 1157
# Got prediction: 1158
# Got prediction: 1159
# Got prediction: 1160
# Saving 1161 responses in file
# Got prediction: 1161
# Got prediction: 1162
# Got prediction: 1163
# Got prediction: 1164
# Got prediction: 1165
# Got prediction: 1166
# Got prediction: 1167
# Got prediction: 1168
# Got prediction: 1169
# Got prediction: 1170
# Saving 1171 responses in file
# Got prediction: 1171
# Got prediction: 1172
# Got prediction: 1173
# Got prediction: 1174
# Got prediction: 1175
# Got prediction: 1176
# Got prediction: 1177
# Got prediction: 1178
# Got prediction: 1179
# Got prediction: 1180
# Saving 1181 responses in file
# Got prediction: 1181
# Got prediction: 1182
# Got prediction: 1183
# Got prediction: 1184
# Got prediction: 1185
# Got prediction: 1186
# Got prediction: 1187
# Got prediction: 1188
# Got prediction: 1189
# Got prediction: 1190
# Saving 1191 responses in file
# Got prediction: 1191
# Got prediction: 1192
# Got prediction: 1193
# Got prediction: 1194
# Got prediction: 1195
# Got prediction: 1196
# Got prediction: 1197
# Got prediction: 1198
# Got prediction: 1199
# Got prediction: 1200
# Saving 1201 responses in file
# Got prediction: 1201
# Got prediction: 1202
# Got prediction: 1203
# Got prediction: 1204
# Got prediction: 1205
# Got prediction: 1206
# Got prediction: 1207
# Got prediction: 1208
# Got prediction: 1209
# Got prediction: 1210
# Saving 1211 responses in file
# Got prediction: 1211
# Got prediction: 1212
# Got prediction: 1213
# Got prediction: 1214
# Got prediction: 1215
# Got prediction: 1216
# Got prediction: 1217
# Got prediction: 1218
# Got prediction: 1219
# Got prediction: 1220
# Saving 1221 responses in file
# Got prediction: 1221
# Got prediction: 1222
# Got prediction: 1223
# Got prediction: 1224
# Got prediction: 1225
# Got prediction: 1226
# Got prediction: 1227
# Got prediction: 1228
# Got prediction: 1229
# Got prediction: 1230
# Saving 1231 responses in file
# Got prediction: 1231
# Got prediction: 1232
# Got prediction: 1233
# Got prediction: 1234
# Got prediction: 1235
# Got prediction: 1236
# Got prediction: 1237
# Got prediction: 1238
# Got prediction: 1239
# Got prediction: 1240
# Saving 1241 responses in file
# Got prediction: 1241
# Got prediction: 1242
# Got prediction: 1243
# Got prediction: 1244
# Got prediction: 1245
# Got prediction: 1246
# Got prediction: 1247
# Got prediction: 1248
# Got prediction: 1249
# Got prediction: 1250
# Saving 1251 responses in file
# Got prediction: 1251
# Got prediction: 1252
# Got prediction: 1253
# Got prediction: 1254
# Got prediction: 1255
# Got prediction: 1256
# Got prediction: 1257
# Got prediction: 1258
# Got prediction: 1259
# Got prediction: 1260
# Saving 1261 responses in file
# Got prediction: 1261
# Got prediction: 1262
# Got prediction: 1263
# Got prediction: 1264
# Got prediction: 1265
# Got prediction: 1266
# Got prediction: 1267
# Got prediction: 1268
# Got prediction: 1269
# Got prediction: 1270
# Saving 1271 responses in file
# Got prediction: 1271
# Got prediction: 1272
# Got prediction: 1273
# Got prediction: 1274
# Got prediction: 1275
# Got prediction: 1276
# Got prediction: 1277
# Got prediction: 1278
# Got prediction: 1279
# Got prediction: 1280
# Saving 1281 responses in file
# Got prediction: 1281
# Got prediction: 1282
# Got prediction: 1283
# Got prediction: 1284
# Got prediction: 1285
# Got prediction: 1286
# Got prediction: 1287
# Got prediction: 1288
# Got prediction: 1289
# Got prediction: 1290
# Saving 1291 responses in file
# Got prediction: 1291
# Got prediction: 1292
# Got prediction: 1293
# Got prediction: 1294
# Got prediction: 1295
# Got prediction: 1296
# Got prediction: 1297
# Got prediction: 1298
# Got prediction: 1299
# Got prediction: 1300
# Saving 1301 responses in file
# Got prediction: 1301
# Got prediction: 1302
# Got prediction: 1303
# Got prediction: 1304
# Got prediction: 1305
# Got prediction: 1306
# Got prediction: 1307
# Got prediction: 1308
# Got prediction: 1309
# Got prediction: 1310
# Saving 1311 responses in file
# Got prediction: 1311
# Got prediction: 1312
# Got prediction: 1313
# Got prediction: 1314
# Got prediction: 1315
# Got prediction: 1316
# Got prediction: 1317
# Got prediction: 1318
# Got prediction: 1319
# Got prediction: 1320
# Saving 1321 responses in file
# Got prediction: 1321
# Got prediction: 1322
# Got prediction: 1323
# Got prediction: 1324
# Got prediction: 1325
# Got prediction: 1326
# Got prediction: 1327
# Got prediction: 1328
# Got prediction: 1329
# Got prediction: 1330
# Saving 1331 responses in file
# Got prediction: 1331
# Got prediction: 1332
# Got prediction: 1333
# Got prediction: 1334
# Got prediction: 1335
# Got prediction: 1336
# Got prediction: 1337
# Got prediction: 1338
# Got prediction: 1339
# Got prediction: 1340
# Saving 1341 responses in file
# Got prediction: 1341
# Got prediction: 1342
# Got prediction: 1343
# Got prediction: 1344
# Got prediction: 1345
# Got prediction: 1346
# Got prediction: 1347
# Got prediction: 1348
# Got prediction: 1349
# Got prediction: 1350
# Saving 1351 responses in file
# Got prediction: 1351
# Got prediction: 1352
# Got prediction: 1353
# Got prediction: 1354
# Got prediction: 1355
# Got prediction: 1356
# Got prediction: 1357
# Got prediction: 1358
# Got prediction: 1359
# Got prediction: 1360
# Saving 1361 responses in file
# Got prediction: 1361
# Got prediction: 1362
# Got prediction: 1363
# Got prediction: 1364
# Got prediction: 1365
# Got prediction: 1366
# Got prediction: 1367
# Got prediction: 1368
# Got prediction: 1369
# Got prediction: 1370
# Saving 1371 responses in file
# Got prediction: 1371
# Got prediction: 1372
# Got prediction: 1373
# Got prediction: 1374
# Got prediction: 1375
# Got prediction: 1376
# Got prediction: 1377
# Got prediction: 1378
# Got prediction: 1379
# Got prediction: 1380
# Saving 1381 responses in file
# Got prediction: 1381
# Got prediction: 1382
# Got prediction: 1383
# Got prediction: 1384
# Got prediction: 1385
# Got prediction: 1386
# Got prediction: 1387
# Got prediction: 1388
# Got prediction: 1389
# Got prediction: 1390
# Saving 1391 responses in file
# Got prediction: 1391
# Got prediction: 1392
# Got prediction: 1393
# Got prediction: 1394
# Got prediction: 1395
# Got prediction: 1396
# Got prediction: 1397
# Got prediction: 1398
# Got prediction: 1399
# Got prediction: 1400
# Saving 1401 responses in file
# Got prediction: 1401
# Got prediction: 1402
# Got prediction: 1403
# Got prediction: 1404
# Got prediction: 1405
# Got prediction: 1406
# Got prediction: 1407
# Got prediction: 1408
# Got prediction: 1409
# Got prediction: 1410
# Saving 1411 responses in file
# Got prediction: 1411
# Got prediction: 1412
# Got prediction: 1413
# Got prediction: 1414
# Got prediction: 1415
# Got prediction: 1416
# Got prediction: 1417
# Got prediction: 1418
# Got prediction: 1419
# Got prediction: 1420
# Saving 1421 responses in file
# Got prediction: 1421
# Got prediction: 1422
# Got prediction: 1423
# Got prediction: 1424
# Got prediction: 1425
# Got prediction: 1426
# Got prediction: 1427
# Got prediction: 1428
# Got prediction: 1429
# Got prediction: 1430
# Saving 1431 responses in file
# Got prediction: 1431
# Got prediction: 1432
# Got prediction: 1433
# Got prediction: 1434
# Got prediction: 1435
# Got prediction: 1436
# Got prediction: 1437
# Got prediction: 1438
# Got prediction: 1439
# Got prediction: 1440
# Saving 1441 responses in file
# Got prediction: 1441
# Got prediction: 1442
# Got prediction: 1443
# Got prediction: 1444
# Got prediction: 1445
# Got prediction: 1446
# Got prediction: 1447
# Got prediction: 1448
# Got prediction: 1449
# Got prediction: 1450
# Saving 1451 responses in file
# Got prediction: 1451
# Got prediction: 1452
# Got prediction: 1453
# Got prediction: 1454
# Got prediction: 1455
# Got prediction: 1456
# Got prediction: 1457
# Got prediction: 1458
# Got prediction: 1459
# Got prediction: 1460
# Saving 1461 responses in file
# Got prediction: 1461
# Got prediction: 1462
# Got prediction: 1463
# Got prediction: 1464
# Got prediction: 1465
# Got prediction: 1466
# Got prediction: 1467
# Got prediction: 1468
# Got prediction: 1469
# Got prediction: 1470
# Saving 1471 responses in file
# Got prediction: 1471
# Got prediction: 1472
# Got prediction: 1473
# Got prediction: 1474
# Got prediction: 1475
# Got prediction: 1476
# Got prediction: 1477
# Got prediction: 1478
# Got prediction: 1479
# Got prediction: 1480
# Saving 1481 responses in file
# Got prediction: 1481
# Got prediction: 1482
# Got prediction: 1483
# Got prediction: 1484
# Got prediction: 1485
# Got prediction: 1486
# Got prediction: 1487
# Got prediction: 1488
# Got prediction: 1489
# Got prediction: 1490
# Saving 1491 responses in file
# Got prediction: 1491
# Got prediction: 1492
# Got prediction: 1493
# Got prediction: 1494
# Got prediction: 1495
# Got prediction: 1496
# Got prediction: 1497
# Got prediction: 1498
# Got prediction: 1499
# Got prediction: 1500
# Saving 1501 responses in file
# Got prediction: 1501
# Got prediction: 1502
# Got prediction: 1503
# Got prediction: 1504
# Got prediction: 1505
# Got prediction: 1506
# Got prediction: 1507
# Got prediction: 1508
# Got prediction: 1509
# Got prediction: 1510
# Saving 1511 responses in file
# Got prediction: 1511
# Got prediction: 1512
# Got prediction: 1513
# Got prediction: 1514
# Got prediction: 1515
# Got prediction: 1516
# Got prediction: 1517
# Got prediction: 1518
# Got prediction: 1519
# Got prediction: 1520
# Saving 1521 responses in file
# Got prediction: 1521
# Got prediction: 1522
# Got prediction: 1523
# Got prediction: 1524
# Got prediction: 1525
# Got prediction: 1526
# Got prediction: 1527
# Got prediction: 1528
# Got prediction: 1529
# Got prediction: 1530
# Saving 1531 responses in file
# Got prediction: 1531
# Got prediction: 1532
# Got prediction: 1533
# Got prediction: 1534
# Got prediction: 1535
# Got prediction: 1536
# Got prediction: 1537
# Got prediction: 1538
# Got prediction: 1539
# Got prediction: 1540
# Saving 1541 responses in file
# Got prediction: 1541
# Got prediction: 1542
# Got prediction: 1543
# Got prediction: 1544
# Got prediction: 1545
# Got prediction: 1546
# Got prediction: 1547
# Got prediction: 1548
# Got prediction: 1549
# Got prediction: 1550
# Saving 1551 responses in file
# Got prediction: 1551
# Got prediction: 1552
# Got prediction: 1553
# Got prediction: 1554
# Got prediction: 1555
# Got prediction: 1556
# Got prediction: 1557
# Got prediction: 1558
# Got prediction: 1559
# Got prediction: 1560
# Saving 1561 responses in file
# Got prediction: 1561
# Got prediction: 1562
# Got prediction: 1563
# Got prediction: 1564
# Got prediction: 1565
# Got prediction: 1566
# Got prediction: 1567
# Got prediction: 1568
# Got prediction: 1569
# Got prediction: 1570
# Saving 1571 responses in file
# Got prediction: 1571
# Got prediction: 1572
# Got prediction: 1573
# Got prediction: 1574
# Got prediction: 1575
# Got prediction: 1576
# Got prediction: 1577
# Got prediction: 1578
# Got prediction: 1579
# Got prediction: 1580
# Saving 1581 responses in file
# Got prediction: 1581
# Got prediction: 1582
# Got prediction: 1583
# Got prediction: 1584
# Got prediction: 1585
# Got prediction: 1586
# Got prediction: 1587
# Got prediction: 1588
# Got prediction: 1589
# Got prediction: 1590
# Saving 1591 responses in file
# Got prediction: 1591
# Got prediction: 1592
# Got prediction: 1593
# Got prediction: 1594
# Got prediction: 1595
# Got prediction: 1596
# Got prediction: 1597
# Got prediction: 1598
# Got prediction: 1599
# Got prediction: 1600
# Saving 1601 responses in file
# Got prediction: 1601
# Got prediction: 1602
# Got prediction: 1603
# Got prediction: 1604
# Got prediction: 1605
# Got prediction: 1606
# Got prediction: 1607
# Got prediction: 1608
# Got prediction: 1609
# Got prediction: 1610
# Saving 1611 responses in file
# Got prediction: 1611
# Got prediction: 1612
# Got prediction: 1613
# Got prediction: 1614
# Got prediction: 1615
# Got prediction: 1616
# Got prediction: 1617
# Got prediction: 1618
# Got prediction: 1619
# Got prediction: 1620
# Saving 1621 responses in file
# Got prediction: 1621
# Got prediction: 1622
# Got prediction: 1623
# Got prediction: 1624
# Got prediction: 1625
# Got prediction: 1626
# Got prediction: 1627
# Got prediction: 1628
# Got prediction: 1629
# Got prediction: 1630
# Saving 1631 responses in file
# Got prediction: 1631
# Got prediction: 1632
# Got prediction: 1633
# Got prediction: 1634
# Got prediction: 1635
# Got prediction: 1636
# Got prediction: 1637
# Got prediction: 1638
# Got prediction: 1639
# Got prediction: 1640
# Saving 1641 responses in file
# Got prediction: 1641
# Got prediction: 1642
# Got prediction: 1643
# Got prediction: 1644
# Got prediction: 1645
# Got prediction: 1646
# Got prediction: 1647
# Got prediction: 1648
# Got prediction: 1649
# Got prediction: 1650
# Saving 1651 responses in file
# Got prediction: 1651
# Got prediction: 1652
# Got prediction: 1653
# Got prediction: 1654
# Got prediction: 1655
# Got prediction: 1656
# Got prediction: 1657
# Got prediction: 1658
# Got prediction: 1659
# Got prediction: 1660
# Saving 1661 responses in file
# Got prediction: 1661
# Got prediction: 1662
# Got prediction: 1663
# Got prediction: 1664
# Got prediction: 1665
# Got prediction: 1666
# Got prediction: 1667
# Got prediction: 1668
# Got prediction: 1669
# Got prediction: 1670
# Saving 1671 responses in file
# Got prediction: 1671
# Got prediction: 1672
# Got prediction: 1673
# Got prediction: 1674
# Got prediction: 1675
# Got prediction: 1676
# Got prediction: 1677
# Got prediction: 1678
# Got prediction: 1679
# Got prediction: 1680
# Saving 1681 responses in file
# Got prediction: 1681
# Got prediction: 1682
# Got prediction: 1683
# Got prediction: 1684
# Got prediction: 1685
# Got prediction: 1686
# Got prediction: 1687
# Got prediction: 1688
# Got prediction: 1689
# Got prediction: 1690
# Saving 1691 responses in file
# Got prediction: 1691
# Got prediction: 1692
# Got prediction: 1693
# Got prediction: 1694
# Got prediction: 1695
# Got prediction: 1696
# Got prediction: 1697
# Got prediction: 1698
# Got prediction: 1699
# Got prediction: 1700
# Saving 1701 responses in file
# Got prediction: 1701
# Got prediction: 1702
# Got prediction: 1703
# Got prediction: 1704
# Got prediction: 1705
# Got prediction: 1706
# Got prediction: 1707
# Got prediction: 1708
# Got prediction: 1709
# Got prediction: 1710
# Saving 1711 responses in file
# Got prediction: 1711
# Got prediction: 1712
# Got prediction: 1713
# Got prediction: 1714
# Got prediction: 1715
# Got prediction: 1716
# Got prediction: 1717
# Got prediction: 1718
# Got prediction: 1719
# Got prediction: 1720
# Saving 1721 responses in file
# Got prediction: 1721
# Got prediction: 1722
# Got prediction: 1723
# Got prediction: 1724
# Got prediction: 1725
# Got prediction: 1726
# Got prediction: 1727
# Got prediction: 1728
# Got prediction: 1729
# Got prediction: 1730
# Saving 1731 responses in file
# Got prediction: 1731
# Got prediction: 1732
# Got prediction: 1733
# Got prediction: 1734
# Got prediction: 1735
# Got prediction: 1736
# Got prediction: 1737
# Got prediction: 1738
# Got prediction: 1739
# Got prediction: 1740
# Saving 1741 responses in file
# Got prediction: 1741
# Got prediction: 1742
# Got prediction: 1743
# Got prediction: 1744
# Got prediction: 1745
# Got prediction: 1746
# Got prediction: 1747
# Got prediction: 1748
# Got prediction: 1749
# Got prediction: 1750
# Saving 1751 responses in file
# Got prediction: 1751
# Got prediction: 1752
# Got prediction: 1753
# Got prediction: 1754
# Got prediction: 1755
# Got prediction: 1756
# Got prediction: 1757
# Got prediction: 1758
# Got prediction: 1759
# Got prediction: 1760
# Saving 1761 responses in file
# Got prediction: 1761
# Got prediction: 1762
# Got prediction: 1763
# Got prediction: 1764
# Got prediction: 1765
# Got prediction: 1766
# Got prediction: 1767
# Got prediction: 1768
# Got prediction: 1769
# Got prediction: 1770
# Saving 1771 responses in file
# Got prediction: 1771
# Got prediction: 1772
# Got prediction: 1773
# Got prediction: 1774
# Got prediction: 1775
# Got prediction: 1776
# Got prediction: 1777
# Got prediction: 1778
# Got prediction: 1779
# Got prediction: 1780
# Saving 1781 responses in file
# Got prediction: 1781
# Got prediction: 1782
# Got prediction: 1783
# Got prediction: 1784
# Got prediction: 1785
# Got prediction: 1786
# Got prediction: 1787
# Got prediction: 1788
# Got prediction: 1789
# Got prediction: 1790
# Saving 1791 responses in file
# Got prediction: 1791
# Got prediction: 1792
# Got prediction: 1793
# Got prediction: 1794
# Got prediction: 1795
# Got prediction: 1796
# Got prediction: 1797
# Got prediction: 1798
# Got prediction: 1799
# Got prediction: 1800
# Saving 1801 responses in file
# Got prediction: 1801
# Got prediction: 1802
# Got prediction: 1803
# Got prediction: 1804
# Got prediction: 1805
# Got prediction: 1806
# Got prediction: 1807
# Got prediction: 1808
# Got prediction: 1809
# Got prediction: 1810
# Saving 1811 responses in file
# Got prediction: 1811
# Got prediction: 1812
# Got prediction: 1813
# Got prediction: 1814
# Got prediction: 1815
# Got prediction: 1816
# Got prediction: 1817
# Got prediction: 1818
# Got prediction: 1819
# Got prediction: 1820
# Saving 1821 responses in file
# Got prediction: 1821
# Got prediction: 1822
# Got prediction: 1823
# Got prediction: 1824
# Got prediction: 1825
# Got prediction: 1826
# Got prediction: 1827
# Got prediction: 1828
# Got prediction: 1829
# Got prediction: 1830
# Saving 1831 responses in file
# Got prediction: 1831
# Got prediction: 1832
# Got prediction: 1833
# Got prediction: 1834
# Got prediction: 1835
# Got prediction: 1836
# Got prediction: 1837
# Got prediction: 1838
# Got prediction: 1839
# Got prediction: 1840
# Saving 1841 responses in file
# Got prediction: 1841
# Got prediction: 1842
# Got prediction: 1843
# Got prediction: 1844
# Got prediction: 1845
# Got prediction: 1846
# Got prediction: 1847
# Got prediction: 1848
# Got prediction: 1849
# Got prediction: 1850
# Saving 1851 responses in file
# Got prediction: 1851
# Got prediction: 1852
# Got prediction: 1853
# Got prediction: 1854
# Got prediction: 1855
# Got prediction: 1856
# Got prediction: 1857
# Got prediction: 1858
# Got prediction: 1859
# Got prediction: 1860
# Saving 1861 responses in file
# Got prediction: 1861
# Got prediction: 1862
# Got prediction: 1863
# Got prediction: 1864
# Got prediction: 1865
# Got prediction: 1866
# Got prediction: 1867
# Got prediction: 1868
# Got prediction: 1869
# Got prediction: 1870
# Saving 1871 responses in file
# Got prediction: 1871
# Got prediction: 1872
# Got prediction: 1873
# Got prediction: 1874
# Got prediction: 1875
# Got prediction: 1876
# Got prediction: 1877
# Got prediction: 1878
# Got prediction: 1879
# Got prediction: 1880
# Saving 1881 responses in file
# Got prediction: 1881
# Got prediction: 1882
# Got prediction: 1883
# Got prediction: 1884
# Got prediction: 1885
# Got prediction: 1886
# Got prediction: 1887
# Got prediction: 1888
# Got prediction: 1889
# Got prediction: 1890
# Saving 1891 responses in file
# Got prediction: 1891
# Got prediction: 1892
# Got prediction: 1893
# Got prediction: 1894
# Got prediction: 1895
# Got prediction: 1896
# Got prediction: 1897
# Got prediction: 1898
# Got prediction: 1899
# Got prediction: 1900
# Saving 1901 responses in file
# Got prediction: 1901
# Got prediction: 1902
# Got prediction: 1903
# Got prediction: 1904
# Got prediction: 1905
# Got prediction: 1906
# Got prediction: 1907
# Got prediction: 1908
# Got prediction: 1909
# Got prediction: 1910
# Saving 1911 responses in file
# Got prediction: 1911
# Got prediction: 1912
# Got prediction: 1913
# Got prediction: 1914
# Got prediction: 1915
# Got prediction: 1916
# Got prediction: 1917
# Got prediction: 1918
# Got prediction: 1919
# Got prediction: 1920
# Saving 1921 responses in file
# Got prediction: 1921
# Got prediction: 1922

# %%
responses_original_model = load_responses(dataset_chatml['test'], 'original_model.json', original_pipeline, tokenizer)

# %%
responses_original_model_train = load_responses(dataset_chatml['train'], 'original_model_train.json', original_pipeline, tokenizer)

# %% [markdown]
# ## Model Responses

# %%
model_responses_df = pd.read_json('fine_tuned_model.json') # model responses for testing
model_responses_df.columns = ['input', 'output']
model_responses_df.head()
# Out:
#                                                input  \
# 0  i want a secure relationship with someone that...
# 1  my boyfriend is in recovery from drug addictio...
# 2  is this something i should be worried about sh...
# 3  my friend is abusing her prescription medicine...
# 4  i terminated my counseling relationship with a...
#
#                                               output
# 0  It sounds like you're going through a really t...
# 1  I'm truly sorry to hear that you're going thro...
# 2  I'm really glad you're reaching out and sharin...
# 3  I'm really sorry to hear that you're going thr...
# 4  I'm really glad to hear that you're considerin...

# %%
original_model_responses_df = pd.read_json('original_model.json') # model responses for testing
original_model_responses_df.columns = ['input', 'output']
original_model_responses_df.head()
# Out:
#                                                input  \
# 0  i want a secure relationship with someone that...
# 1  my boyfriend is in recovery from drug addictio...
# 2  is this something i should be worried about sh...
# 3  my friend is abusing her prescription medicine...
# 4  i terminated my counseling relationship with a...
#
#                                               output
# 0  I hear you, and it sounds like you're going th...
# 1  I'm truly sorry to hear that you're going thro...
# 2  I'm really glad you're reaching out to talk ab...
# 3  I'm really concerned to hear about what you're...
# 4  I'm really sorry to hear that you've been havi...

# %%
model_train_responses_df = pd.read_json('fine_tuned_train_model0.json') # model responses for training
model_train_responses_df.columns = ['input', 'output']
model_train_responses_df.head()
# Out:
#                                                input  \
# 0  i do not love my sister i would never wish her...
# 1  every winter i find myself getting sad because...
# 2  i keep having these random thoughts that i do ...
# 3  i feel like i was born in the wrong body i fee...
# 4  my boyfriend is in ireland for days and i am a...
#
#                                               output
# 0  I hear you expressing a complex mix of emotion...
# 1  I'm really glad you've reached out and shared ...
# 2  I'm really sorry to hear that you're going thr...
# 3  I'm really sorry to hear that you're feeling t...
# 4  I'm really sorry to hear that you're feeling t...

# %%
model_train_responses_df.shape
# Out:
# (1891, 2)

# %%
train_df = dataset_chatml['train'].to_pandas(["input", "output"])

# %%
model_train_responses_df['therapist_output'] = train_df['output'][:model_train_responses_df.shape[0]]

# %%
original_model_responses_df.shape
# Out:
# (138, 2)

# %%
model_responses_df.shape
# Out:
# (138, 2)

# %%
test_df = dataset_chatml['test'].to_pandas(["input", "output"])

# %%
model_responses_df['therapist_output'] = test_df['output']

# %%
model_responses_df.shape
# Out:
# (138, 3)

# %%
original_model_responses_df['therapist_output'] = test_df['output']

# %%
original_model_responses_df.to_csv('original_model_responses.csv') # saving as csv

# %%
model_responses_df.to_csv('model_responses.csv') # saving as csv

# %%
model_train_responses_df.to_csv('model_train_responses.csv', index=False) # saving as csv

# %%
model_responses_df.head()
# Out:
#                                                input  \
# 0  i want a secure relationship with someone that...
# 1  my boyfriend is in recovery from drug addictio...
# 2  is this something i should be worried about sh...
# 3  my friend is abusing her prescription medicine...
# 4  i terminated my counseling relationship with a...
#
#                                               output  \
# 0  It sounds like you're going through a really t...
# 1  I'm truly sorry to hear that you're going thro...
# 2  I'm really glad you're reaching out and sharin...
# 3  I'm really sorry to hear that you're going thr...
# 4  I'm really glad to hear that you're considerin...
#
#                                     therapist_output
# 0  good for you on your keen awareness of your di...
# 1  my empathy goes out to you relationships are t...
# 2  it can be tricky to figure out if a child is t...
# 3  first of all where did you find the pills did ...
# 4  yes your former social worker should return yo...

# %%
model_responses_df.to_excel('model_responses.xlsx') # saving as excel

# %%
original_model_responses_df.to_excel('original_model_responses.xlsx') # saving as excel

# %% [markdown]
# ## Rouge Test

# %%
from model_tester import ModelTester

# %%
model_responses_df = pd.read_csv('model_responses.csv')

# %%
original_model_responses_df = pd.read_csv('original_model_responses.csv')

# %%
model_train_responses_df = pd.read_csv('model_train_responses.csv')

# %%
model_train_responses_df.shape
# Out:
# (1891, 3)

# %%
finetune_model_tester = ModelTester(model_responses_df['therapist_output'], model_responses_df['output']) # Initiate tester class
finetune_model_tester.calculate_rouge_score() # Calculate Rouge Score
rouge_score = finetune_model_tester.test_results
rouge_score_df = pd.DataFrame(rouge_score)
rouge_score_df.head()
# Out:
#              rouge1    rouge2    rougeL
# precision  0.345152  0.041858  0.165014
# recall     0.315464  0.036597  0.156128
# fmeasure   0.300732  0.035537  0.145425

# %%
original_model_tester = ModelTester(original_model_responses_df['therapist_output'], original_model_responses_df['output']) # Initiate tester class
original_model_tester.calculate_rouge_score() # Calculate Rouge Score
original_rouge_score = original_model_tester.test_results
original_rouge_score_df = pd.DataFrame(original_rouge_score)
original_rouge_score_df.head()
# Out:
#              rouge1    rouge2    rougeL
# precision  0.346590  0.040629  0.169133
# recall     0.303819  0.033308  0.151799
# fmeasure   0.293892  0.033484  0.144125

# %%
model_train_tester = ModelTester(model_train_responses_df['therapist_output'], model_train_responses_df['output']) # Initiate tester class
model_train_tester.calculate_rouge_score() # Calculate Rouge Score
model_train_rouge_score = model_train_tester.test_results
model_train_rouge_score_df = pd.DataFrame(model_train_rouge_score)
model_train_rouge_score_df.head()
# Out:
#              rouge1    rouge2    rougeL
# precision  0.343122  0.043622  0.164482
# recall     0.329095  0.039788  0.163465
# fmeasure   0.303918  0.037534  0.147016

# %% [markdown]
# ## LLM Test

# %%
import re
import requests
from google.colab import userdata

# %%
# Hugging Face API configuration

api_token = userdata.get('HF_TOKEN')

# Headers for the request
headers = {
    "Authorization": f"Bearer {api_token}"
}

# The model to use
model_name = "mistralai/Mistral-7B-v0.1"

# The endpoint for the Hugging Face inference API
api_url = f"https://api-inference.huggingface.co/models/{model_name}"

# %% [markdown]
# ### Testing Phi3

# %%
def create_template(text_1, text_2, input):
  prompt = f"""
    You will be given a user_question, a mental_health_therapist_answer and a machine_generated_answer.
    Your task is to provide a 'total rating' scoring how well the machine_generated_answer answers
    the user concerns expressed in the user_question. Use the mental_health_therapist_answer as example of
    a good answer. Give your answer as a float on a scale of 0 to 10, where 0 means that the
    machine_generated_answer is not helpful at all, and 10 means that the answer completely and helpfully
    addresses the user_question.

    Provide your feedback as follows:

    Feedback:::
    Total rating: (your rating, as a float between 0 and 10)

    Now here are the question and answers.

    User Question: {input}
    Mental Health Therapist Answer: {text_1}
    Machine Generated Answer: {text_2}

    Feedback:::
    Total rating: """

  return prompt

def get_llm_scores(model_name, prompt, api_url):

  # The data payload for the POST request
  data = {
      "inputs": prompt,
      "parameters": {
          "max_length": 100,
          "num_return_sequences": 1
      }
  }

  # Make the request to the API
  response = requests.post(api_url, headers=headers, json=data)

  # Parse the response
  if response.status_code == 200:
      response_data = response.json()
      generated_text = response_data[0]["generated_text"]
      similarity_score = re.search(r'Total rating: (\d+\.\d+)', generated_text)

      if similarity_score:
          score = float(similarity_score.group(1))
          print(f"Similarity Score: {score}")
          return score
      else:
          print("Similarity score not found in the response.")
          return None
  else:
      print(f"Request failed with status code {response.status_code}: {response.text}")
      return None

# %%
result = [] # calculating the score using LLMs for fine-tuned model

for i in range(model_responses_df.shape[0]):
  prompt = create_template(model_responses_df['therapist_output'][i], model_responses_df['output'][i], model_responses_df['input'][i])
  score = get_llm_scores(model_name, prompt, api_url)
  result.append(score)
# Out:
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 5.0
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 0.0
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 5.0
# Similarity Score: 0.0
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5

# %%
df_llm_eval = pd.DataFrame(result, columns=["acorreal/phi3-mental-health"])
df_llm_eval.head()
# Out:
#    acorreal/phi3-mental-health
# 0                          7.5
# 1                          8.5
# 2                          7.5
# 3                          7.5
# 4                          8.5

# %%
df_llm_eval.to_csv('llm_eval.csv')

# %%
df_llm_eval = pd.read_csv('llm_eval.csv')
df_llm_eval.head()
# Out:
#    Unnamed: 0  acorreal/phi3-mental-health
# 0           0                          7.5
# 1           1                          8.5
# 2           2                          7.5
# 3           3                          7.5
# 4           4                          8.5

# %%
result = [] # calculating the score using LLMs for the original model

for i in range(original_model_responses_df.shape[0]):
  prompt = create_template(original_model_responses_df['therapist_output'][i], original_model_responses_df['output'][i], original_model_responses_df['input'][i])
  score = get_llm_scores(model_name, prompt, api_url)
  result.append(score)
# Out:
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity score not found in the response.
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 0.0
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 5.0
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 5.0
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 0.0
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 5.0
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 8.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5
# Similarity Score: 7.5

# %% [markdown]
# ## Comparing Models

# %%
df_llm_eval = pd.read_csv('llm_eval.csv')
df_llm_eval[['acorreal/phi3-mental-health']].mean()
# Out:
# acorreal/phi3-mental-health    7.601449
# dtype: float64

# %%
df_llm_eval["microsoft/Phi-3-mini-4k-instruct"] = result

# %%
df_llm_eval.head()
# Out:
#    Unnamed: 0  acorreal/phi3-mental-health  microsoft/Phi-3-mini-4k-instruct
# 0           0                          7.5                               7.5
# 1           1                          8.5                               7.5
# 2           2                          7.5                               7.5
# 3           3                          7.5                               7.5
# 4           4                          8.5                               7.5

# %%
df_llm_eval.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_llm_eval.to_csv('llm_eval.csv', index=False)

# %%
df_llm_eval = pd.read_csv('llm_eval.csv')
df_llm_eval.head()
# Out:
#    acorreal/phi3-mental-health  microsoft/Phi-3-mini-4k-instruct
# 0                          7.5                               7.5
# 1                          8.5                               7.5
# 2                          7.5                               7.5
# 3                          7.5                               7.5
# 4                          8.5                               7.5

# %%
llm_test_result = df_llm_eval.mean().to_frame(name='mean').T

# %%
llm_test_result
# Out:
#       acorreal/phi3-mental-health  microsoft/Phi-3-mini-4k-instruct
# mean                     7.601449                          7.525547

# %%
df_llm_eval_train = pd.DataFrame(result, columns=["acorreal/phi3-mental-health/train"])
df_llm_eval_train.head()

# %%
result = [] # calculating the score using LLMs for fine-tuned model with training set
counter = 0
for i in range(model_train_responses_df.shape[0]):
  prompt = create_template(model_train_responses_df['therapist_output'][i], model_train_responses_df['output'][i], model_train_responses_df['input'][i])
  score = get_llm_scores(model_name, prompt, api_url)
  result.append(score)
  counter += 1
  if counter % 100 == 0:
    print(f"Saving {len(result)} responses in file")
    with open('llm_eval_train.json', 'w') as f:
        json.dump(result, f)

# %%
import numpy as np

# %%
# read result from json
with open('llm_eval_train.json', 'r') as f:
    result = json.load(f)

# %%
result = result[:300]

# %%
result = np.array(result, dtype=np.float64)

# %%
result = np.array(result)
result = result[~np.isnan(result)]

# %%
llm_test_result['acorreal/phi3-mental-health/train'] = np.array(result).mean()

# %%
llm_test_result
# Out:
#       acorreal/phi3-mental-health  microsoft/Phi-3-mini-4k-instruct  \
# mean                     7.601449                          7.525547
#
#       acorreal/phi3-mental-health/train
# mean                           7.611864
