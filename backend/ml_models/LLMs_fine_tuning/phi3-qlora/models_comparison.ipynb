# %% [markdown]
# # Comparing Models Performance

# %%
# !pip install rouge_score
# Out:
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.4)

# %% [markdown]
# ## Importing modules

# %%
# Get the scripts from remote source
# !git clone https://github.com/mlgomez0/Health_Therapist
# !mv Health_Therapist/backend/ml_models/modules .
# !mv Health_Therapist/backend/ml_models/datasets .
# !mv Health_Therapist/backend/ml_models/LLMs_fine_tuning/phi3-qlora .
# !mv Health_Therapist/requirements.txt .
# !rm -rf Health_Therapist
# Out:
# Cloning into 'Health_Therapist'...
# remote: Enumerating objects: 646, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 646 (delta 11), reused 11 (delta 1), pack-reused 585
# Receiving objects: 100% (646/646), 22.83 MiB | 8.02 MiB/s, done.
# Resolving deltas: 100% (253/253), done.
# mv: cannot move 'Health_Therapist/backend/ml_models/modules' to './modules': Directory not empty
# mv: cannot move 'Health_Therapist/backend/ml_models/datasets' to './datasets': Directory not empty
# mv: cannot move 'Health_Therapist/backend/ml_models/LLMs_fine_tuning/phi3-qlora' to './phi3-qlora': Directory not empty

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import NMF
from sklearn.pipeline import Pipeline
import numpy as np
from scipy import stats
from scipy.stats import wilcoxon

# %%
fine_tuned_phi3_model_responses = pd.read_csv('phi3-qlora/model_responses.csv', index_col=False)
original_phi3_model_responses = pd.read_csv('phi3-qlora/original_model_responses.csv', index_col=False)

# %%
fine_tuned_phi3_model_responses.head()
# Out:
#                                                input  \
# 0  i want a secure relationship with someone that...
# 1  my boyfriend is in recovery from drug addictio...
# 2  is this something i should be worried about sh...
# 3  my friend is abusing her prescription medicine...
# 4  i terminated my counseling relationship with a...
#
#                                               output  \
# 0  It sounds like you're going through a really t...
# 1  I'm truly sorry to hear that you're going thro...
# 2  I'm really glad you're reaching out and sharin...
# 3  I'm really sorry to hear that you're going thr...
# 4  I'm really glad to hear that you're considerin...
#
#                                     therapist_output
# 0  good for you on your keen awareness of your di...
# 1  my empathy goes out to you relationships are t...
# 2  it can be tricky to figure out if a child is t...
# 3  first of all where did you find the pills did ...
# 4  yes your former social worker should return yo...

# %% [markdown]
# ## Topic Modeling

# %%
text = fine_tuned_phi3_model_responses['input'] + ' ' + fine_tuned_phi3_model_responses['therapist_output']

# %%
df = pd.read_csv('datasets/dataset.csv')

# %%
vectorizer = CountVectorizer(min_df=10, max_df=0.5, stop_words="english") # To transform the text into a numerical representation
topic_model = NMF(n_components=10)

topic_pipeline = Pipeline(
    [
        ("vectorizer", vectorizer),
        ("topic_model", topic_model),
    ]
)

# %%
topic_pipeline.fit(text)
# Out:
# Pipeline(steps=[('vectorizer',
#                  CountVectorizer(max_df=0.5, min_df=10, stop_words='english')),
#                 ('topic_model', NMF(n_components=10))])

# %%
# dictionary to map the topics

topics_map = {
    0: "Work-Life Balance",
    1: "Other",
    2: "Romantic Relationships",
    3: "Therapy and Therapist",
    4: "Negative Thoughts",
    5: "Parenthood",
    6: "People Feelings",
    7: "Anxiety and Depression",
    8: "Anxiety and Depression",
    9: "Counseling Issues"
}

# %%
topics = topic_pipeline.transform(text)
topics = np.argmax(topics, axis=1)
topic_names = [topics_map[topic] for topic in topics]

# %% [markdown]
# ## Rouge Score with Topic Modeling

# %%
from modules.model_tester import ModelTester

# %%
rouge_tester_fine_tuned = ModelTester(fine_tuned_phi3_model_responses['therapist_output'], fine_tuned_phi3_model_responses['output'])
rouge_tester_original = ModelTester(original_phi3_model_responses['therapist_output'], original_phi3_model_responses['output'])

# %%
rouge_scores_fine_tuned = rouge_tester_fine_tuned.calculate_rouge_score_by_item()
rouge_scores_original = rouge_tester_original.calculate_rouge_score_by_item()

# %%
len(rouge_scores_fine_tuned['rouge1']['precision'])
# Out:
# 138

# %%
rouge_df = pd.DataFrame()

# %%
for key in rouge_scores_fine_tuned.keys():
  for val in rouge_scores_fine_tuned[key].keys():
    fine_tuned_model_name = "fine-tuned_" + key + "_" + val
    original_model_name = "original_" + key + "_" + val
    rouge_df[fine_tuned_model_name] = rouge_scores_fine_tuned[key][val]
    rouge_df[original_model_name] = rouge_scores_original[key][val]

rouge_df['topic'] = topic_names
rouge_df.head()
# Out:
#    fine-tuned_rouge1_precision  original_rouge1_precision  \
# 0                     0.336066                   0.295337
# 1                     0.445087                   0.455696
# 2                     0.506667                   0.465517
# 3                     0.521739                   0.542169
# 4                     0.172973                   0.169312
#
#    fine-tuned_rouge1_recall  original_rouge1_recall  \
# 0                  0.312977                0.435115
# 1                  0.375610                0.351220
# 2                  0.102981                0.073171
# 3                  0.186047                0.174419
# 4                  0.367816                0.367816
#
#    fine-tuned_rouge1_fmeasure  original_rouge1_fmeasure  \
# 0                    0.324111                  0.351852
# 1                    0.407407                  0.396694
# 2                    0.171171                  0.126464
# 3                    0.274286                  0.263930
# 4                    0.235294                  0.231884
#
#    fine-tuned_rouge2_precision  original_rouge2_precision  \
# 0                     0.033058                   0.026042
# 1                     0.046512                   0.044586
# 2                     0.027027                   0.000000
# 3                     0.032967                   0.048780
# 4                     0.010870                   0.026596
#
#    fine-tuned_rouge2_recall  original_rouge2_recall  \
# 0                  0.030769                0.038462
# 1                  0.039216                0.034314
# 2                  0.005435                0.000000
# 3                  0.011673                0.015564
# 4                  0.023256                0.058140
#
#    fine-tuned_rouge2_fmeasure  original_rouge2_fmeasure  \
# 0                    0.031873                  0.031056
# 1                    0.042553                  0.038781
# 2                    0.009050                  0.000000
# 3                    0.017241                  0.023599
# 4                    0.014815                  0.036496
#
#    fine-tuned_rougeL_precision  original_rougeL_precision  \
# 0                     0.180328                   0.155440
# 1                     0.179191                   0.170886
# 2                     0.253333                   0.241379
# 3                     0.260870                   0.301205
# 4                     0.086486                   0.111111
#
#    fine-tuned_rougeL_recall  original_rougeL_recall  \
# 0                  0.167939                0.229008
# 1                  0.151220                0.131707
# 2                  0.051491                0.037940
# 3                  0.093023                0.096899
# 4                  0.183908                0.241379
#
#    fine-tuned_rougeL_fmeasure  original_rougeL_fmeasure  \
# 0                    0.173913                  0.185185
# 1                    0.164021                  0.148760
# 2                    0.085586                  0.065574
# 3                    0.137143                  0.146628
# 4                    0.117647                  0.152174
#
#                     topic
# 0  Romantic Relationships
# 1  Romantic Relationships
# 2              Parenthood
# 3         People Feelings
# 4       Counseling Issues

# %%
topics = rouge_df['topic'].unique()
topics
# Out:
# array(['Romantic Relationships', 'Parenthood', 'People Feelings',
#        'Counseling Issues', 'Other', 'Anxiety and Depression',
#        'Negative Thoughts', 'Therapy and Therapist', 'Work-Life Balance'],
#       dtype=object)

# %%
def statistical_test_rouge(data, topics, col1, col2):
  result = []
  for topic in topics:
    data_t = data.loc[data['topic'] == topic]
    data1 = data_t[col1]
    data2 = data_t[col2]
    data1 = data1.dropna()
    data2 = data2.dropna()
    _, p_value = wilcoxon(data1, data2)
    result.append((topic, p_value, len(data1)))
  return result

# %%
def get_rouge_scores_df(data, topics, col1, col2):
  rouge_ttest = statistical_test_rouge(data, topics, col1, col2)
  df_result = data[['topic', col1, col2]].groupby('topic').mean()
  df_result['p_value'] = 0.0
  df_result['n'] = 0
  for result in rouge_ttest:
    df_result.loc[result[0], 'p_value'] = result[1]
    df_result.loc[result[0], 'n'] = result[2]
  return df_result

# %%
from IPython.display import display

# %%
cols = rouge_df.columns
for i in range(0, len(cols) - 1, 2):
  partial_rouge_df = get_rouge_scores_df(rouge_df, topics, cols[i], cols[i + 1])
  print(f"ROUGE scores between {cols[i]} and {cols[i + 1]}:")
  display(partial_rouge_df.style.set_properties(**{'text-align': 'center'}).set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'center')]}]
  ))
  print("\n" + "-"*80 + "\n")
# Out:
# ROUGE scores between fine-tuned_rouge1_precision and original_rouge1_precision:
# <style type="text/css">
# #T_99a2e th {
#   text-align: center;
# }
# #T_99a2e_row0_col0, #T_99a2e_row0_col1, #T_99a2e_row0_col2, #T_99a2e_row0_col3, #T_99a2e_row1_col0, #T_99a2e_row1_col1, #T_99a2e_row1_col2, #T_99a2e_row1_col3, #T_99a2e_row2_col0, #T_99a2e_row2_col1, #T_99a2e_row2_col2, #T_99a2e_row2_col3, #T_99a2e_row3_col0, #T_99a2e_row3_col1, #T_99a2e_row3_col2, #T_99a2e_row3_col3, #T_99a2e_row4_col0, #T_99a2e_row4_col1, #T_99a2e_row4_col2, #T_99a2e_row4_col3, #T_99a2e_row5_col0, #T_99a2e_row5_col1, #T_99a2e_row5_col2, #T_99a2e_row5_col3, #T_99a2e_row6_col0, #T_99a2e_row6_col1, #T_99a2e_row6_col2, #T_99a2e_row6_col3, #T_99a2e_row7_col0, #T_99a2e_row7_col1, #T_99a2e_row7_col2, #T_99a2e_row7_col3, #T_99a2e_row8_col0, #T_99a2e_row8_col1, #T_99a2e_row8_col2, #T_99a2e_row8_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_99a2e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99a2e_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge1_precision</th>
#       <th id="T_99a2e_level0_col1" class="col_heading level0 col1" >original_rouge1_precision</th>
#       <th id="T_99a2e_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_99a2e_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99a2e_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_99a2e_row0_col0" class="data row0 col0" >0.347094</td>
#       <td id="T_99a2e_row0_col1" class="data row0 col1" >0.348194</td>
#       <td id="T_99a2e_row0_col2" class="data row0 col2" >0.879293</td>
#       <td id="T_99a2e_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_99a2e_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_99a2e_row1_col0" class="data row1 col0" >0.301464</td>
#       <td id="T_99a2e_row1_col1" class="data row1 col1" >0.306824</td>
#       <td id="T_99a2e_row1_col2" class="data row1 col2" >0.408243</td>
#       <td id="T_99a2e_row1_col3" class="data row1 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_99a2e_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_99a2e_row2_col0" class="data row2 col0" >0.342085</td>
#       <td id="T_99a2e_row2_col1" class="data row2 col1" >0.367882</td>
#       <td id="T_99a2e_row2_col2" class="data row2 col2" >0.218750</td>
#       <td id="T_99a2e_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_99a2e_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_99a2e_row3_col0" class="data row3 col0" >0.369295</td>
#       <td id="T_99a2e_row3_col1" class="data row3 col1" >0.331799</td>
#       <td id="T_99a2e_row3_col2" class="data row3 col2" >0.015625</td>
#       <td id="T_99a2e_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_99a2e_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_99a2e_row4_col0" class="data row4 col0" >0.320798</td>
#       <td id="T_99a2e_row4_col1" class="data row4 col1" >0.335238</td>
#       <td id="T_99a2e_row4_col2" class="data row4 col2" >0.803955</td>
#       <td id="T_99a2e_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_99a2e_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_99a2e_row5_col0" class="data row5 col0" >0.372615</td>
#       <td id="T_99a2e_row5_col1" class="data row5 col1" >0.379737</td>
#       <td id="T_99a2e_row5_col2" class="data row5 col2" >0.578206</td>
#       <td id="T_99a2e_row5_col3" class="data row5 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_99a2e_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_99a2e_row6_col0" class="data row6 col0" >0.375831</td>
#       <td id="T_99a2e_row6_col1" class="data row6 col1" >0.360225</td>
#       <td id="T_99a2e_row6_col2" class="data row6 col2" >0.088654</td>
#       <td id="T_99a2e_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_99a2e_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_99a2e_row7_col0" class="data row7 col0" >0.301859</td>
#       <td id="T_99a2e_row7_col1" class="data row7 col1" >0.293430</td>
#       <td id="T_99a2e_row7_col2" class="data row7 col2" >0.687500</td>
#       <td id="T_99a2e_row7_col3" class="data row7 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_99a2e_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_99a2e_row8_col0" class="data row8 col0" >0.513283</td>
#       <td id="T_99a2e_row8_col1" class="data row8 col1" >0.538579</td>
#       <td id="T_99a2e_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_99a2e_row8_col3" class="data row8 col3" >2</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rouge1_recall and original_rouge1_recall:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# <style type="text/css">
# #T_02949 th {
#   text-align: center;
# }
# #T_02949_row0_col0, #T_02949_row0_col1, #T_02949_row0_col2, #T_02949_row0_col3, #T_02949_row1_col0, #T_02949_row1_col1, #T_02949_row1_col2, #T_02949_row1_col3, #T_02949_row2_col0, #T_02949_row2_col1, #T_02949_row2_col2, #T_02949_row2_col3, #T_02949_row3_col0, #T_02949_row3_col1, #T_02949_row3_col2, #T_02949_row3_col3, #T_02949_row4_col0, #T_02949_row4_col1, #T_02949_row4_col2, #T_02949_row4_col3, #T_02949_row5_col0, #T_02949_row5_col1, #T_02949_row5_col2, #T_02949_row5_col3, #T_02949_row6_col0, #T_02949_row6_col1, #T_02949_row6_col2, #T_02949_row6_col3, #T_02949_row7_col0, #T_02949_row7_col1, #T_02949_row7_col2, #T_02949_row7_col3, #T_02949_row8_col0, #T_02949_row8_col1, #T_02949_row8_col2, #T_02949_row8_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_02949" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02949_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge1_recall</th>
#       <th id="T_02949_level0_col1" class="col_heading level0 col1" >original_rouge1_recall</th>
#       <th id="T_02949_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_02949_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02949_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_02949_row0_col0" class="data row0 col0" >0.324480</td>
#       <td id="T_02949_row0_col1" class="data row0 col1" >0.316535</td>
#       <td id="T_02949_row0_col2" class="data row0 col2" >0.565645</td>
#       <td id="T_02949_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_02949_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_02949_row1_col0" class="data row1 col0" >0.316336</td>
#       <td id="T_02949_row1_col1" class="data row1 col1" >0.310879</td>
#       <td id="T_02949_row1_col2" class="data row1 col2" >0.886403</td>
#       <td id="T_02949_row1_col3" class="data row1 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_02949_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_02949_row2_col0" class="data row2 col0" >0.368321</td>
#       <td id="T_02949_row2_col1" class="data row2 col1" >0.292958</td>
#       <td id="T_02949_row2_col2" class="data row2 col2" >0.031250</td>
#       <td id="T_02949_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_02949_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_02949_row3_col0" class="data row3 col0" >0.293831</td>
#       <td id="T_02949_row3_col1" class="data row3 col1" >0.272240</td>
#       <td id="T_02949_row3_col2" class="data row3 col2" >0.296875</td>
#       <td id="T_02949_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_02949_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_02949_row4_col0" class="data row4 col0" >0.298963</td>
#       <td id="T_02949_row4_col1" class="data row4 col1" >0.288357</td>
#       <td id="T_02949_row4_col2" class="data row4 col2" >0.388186</td>
#       <td id="T_02949_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_02949_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_02949_row5_col0" class="data row5 col0" >0.313644</td>
#       <td id="T_02949_row5_col1" class="data row5 col1" >0.296986</td>
#       <td id="T_02949_row5_col2" class="data row5 col2" >0.172959</td>
#       <td id="T_02949_row5_col3" class="data row5 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_02949_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_02949_row6_col0" class="data row6 col0" >0.330195</td>
#       <td id="T_02949_row6_col1" class="data row6 col1" >0.336992</td>
#       <td id="T_02949_row6_col2" class="data row6 col2" >0.679116</td>
#       <td id="T_02949_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_02949_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_02949_row7_col0" class="data row7 col0" >0.272494</td>
#       <td id="T_02949_row7_col1" class="data row7 col1" >0.250529</td>
#       <td id="T_02949_row7_col2" class="data row7 col2" >0.562500</td>
#       <td id="T_02949_row7_col3" class="data row7 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_02949_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_02949_row8_col0" class="data row8 col0" >0.218200</td>
#       <td id="T_02949_row8_col1" class="data row8 col1" >0.218232</td>
#       <td id="T_02949_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_02949_row8_col3" class="data row8 col3" >2</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rouge1_fmeasure and original_rouge1_fmeasure:
# <style type="text/css">
# #T_fab17 th {
#   text-align: center;
# }
# #T_fab17_row0_col0, #T_fab17_row0_col1, #T_fab17_row0_col2, #T_fab17_row0_col3, #T_fab17_row1_col0, #T_fab17_row1_col1, #T_fab17_row1_col2, #T_fab17_row1_col3, #T_fab17_row2_col0, #T_fab17_row2_col1, #T_fab17_row2_col2, #T_fab17_row2_col3, #T_fab17_row3_col0, #T_fab17_row3_col1, #T_fab17_row3_col2, #T_fab17_row3_col3, #T_fab17_row4_col0, #T_fab17_row4_col1, #T_fab17_row4_col2, #T_fab17_row4_col3, #T_fab17_row5_col0, #T_fab17_row5_col1, #T_fab17_row5_col2, #T_fab17_row5_col3, #T_fab17_row6_col0, #T_fab17_row6_col1, #T_fab17_row6_col2, #T_fab17_row6_col3, #T_fab17_row7_col0, #T_fab17_row7_col1, #T_fab17_row7_col2, #T_fab17_row7_col3, #T_fab17_row8_col0, #T_fab17_row8_col1, #T_fab17_row8_col2, #T_fab17_row8_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_fab17" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fab17_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge1_fmeasure</th>
#       <th id="T_fab17_level0_col1" class="col_heading level0 col1" >original_rouge1_fmeasure</th>
#       <th id="T_fab17_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_fab17_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fab17_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_fab17_row0_col0" class="data row0 col0" >0.309158</td>
#       <td id="T_fab17_row0_col1" class="data row0 col1" >0.302275</td>
#       <td id="T_fab17_row0_col2" class="data row0 col2" >0.342850</td>
#       <td id="T_fab17_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_fab17_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_fab17_row1_col0" class="data row1 col0" >0.282353</td>
#       <td id="T_fab17_row1_col1" class="data row1 col1" >0.282349</td>
#       <td id="T_fab17_row1_col2" class="data row1 col2" >0.980084</td>
#       <td id="T_fab17_row1_col3" class="data row1 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_fab17_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_fab17_row2_col0" class="data row2 col0" >0.290141</td>
#       <td id="T_fab17_row2_col1" class="data row2 col1" >0.252528</td>
#       <td id="T_fab17_row2_col2" class="data row2 col2" >0.156250</td>
#       <td id="T_fab17_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_fab17_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_fab17_row3_col0" class="data row3 col0" >0.289533</td>
#       <td id="T_fab17_row3_col1" class="data row3 col1" >0.264760</td>
#       <td id="T_fab17_row3_col2" class="data row3 col2" >0.218750</td>
#       <td id="T_fab17_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_fab17_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_fab17_row4_col0" class="data row4 col0" >0.282395</td>
#       <td id="T_fab17_row4_col1" class="data row4 col1" >0.286328</td>
#       <td id="T_fab17_row4_col2" class="data row4 col2" >0.977966</td>
#       <td id="T_fab17_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_fab17_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_fab17_row5_col0" class="data row5 col0" >0.309963</td>
#       <td id="T_fab17_row5_col1" class="data row5 col1" >0.306974</td>
#       <td id="T_fab17_row5_col2" class="data row5 col2" >0.490786</td>
#       <td id="T_fab17_row5_col3" class="data row5 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_fab17_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_fab17_row6_col0" class="data row6 col0" >0.335375</td>
#       <td id="T_fab17_row6_col1" class="data row6 col1" >0.330825</td>
#       <td id="T_fab17_row6_col2" class="data row6 col2" >0.611221</td>
#       <td id="T_fab17_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_fab17_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_fab17_row7_col0" class="data row7 col0" >0.266584</td>
#       <td id="T_fab17_row7_col1" class="data row7 col1" >0.230650</td>
#       <td id="T_fab17_row7_col2" class="data row7 col2" >0.062500</td>
#       <td id="T_fab17_row7_col3" class="data row7 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_fab17_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_fab17_row8_col0" class="data row8 col0" >0.297508</td>
#       <td id="T_fab17_row8_col1" class="data row8 col1" >0.296488</td>
#       <td id="T_fab17_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_fab17_row8_col3" class="data row8 col3" >2</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rouge2_precision and original_rouge2_precision:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# <style type="text/css">
# #T_4f69d th {
#   text-align: center;
# }
# #T_4f69d_row0_col0, #T_4f69d_row0_col1, #T_4f69d_row0_col2, #T_4f69d_row0_col3, #T_4f69d_row1_col0, #T_4f69d_row1_col1, #T_4f69d_row1_col2, #T_4f69d_row1_col3, #T_4f69d_row2_col0, #T_4f69d_row2_col1, #T_4f69d_row2_col2, #T_4f69d_row2_col3, #T_4f69d_row3_col0, #T_4f69d_row3_col1, #T_4f69d_row3_col2, #T_4f69d_row3_col3, #T_4f69d_row4_col0, #T_4f69d_row4_col1, #T_4f69d_row4_col2, #T_4f69d_row4_col3, #T_4f69d_row5_col0, #T_4f69d_row5_col1, #T_4f69d_row5_col2, #T_4f69d_row5_col3, #T_4f69d_row6_col0, #T_4f69d_row6_col1, #T_4f69d_row6_col2, #T_4f69d_row6_col3, #T_4f69d_row7_col0, #T_4f69d_row7_col1, #T_4f69d_row7_col2, #T_4f69d_row7_col3, #T_4f69d_row8_col0, #T_4f69d_row8_col1, #T_4f69d_row8_col2, #T_4f69d_row8_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_4f69d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f69d_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge2_precision</th>
#       <th id="T_4f69d_level0_col1" class="col_heading level0 col1" >original_rouge2_precision</th>
#       <th id="T_4f69d_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_4f69d_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f69d_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_4f69d_row0_col0" class="data row0 col0" >0.042317</td>
#       <td id="T_4f69d_row0_col1" class="data row0 col1" >0.043429</td>
#       <td id="T_4f69d_row0_col2" class="data row0 col2" >0.921715</td>
#       <td id="T_4f69d_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_4f69d_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_4f69d_row1_col0" class="data row1 col0" >0.035695</td>
#       <td id="T_4f69d_row1_col1" class="data row1 col1" >0.034753</td>
#       <td id="T_4f69d_row1_col2" class="data row1 col2" >0.764394</td>
#       <td id="T_4f69d_row1_col3" class="data row1 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_4f69d_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_4f69d_row2_col0" class="data row2 col0" >0.055203</td>
#       <td id="T_4f69d_row2_col1" class="data row2 col1" >0.045224</td>
#       <td id="T_4f69d_row2_col2" class="data row2 col2" >0.156250</td>
#       <td id="T_4f69d_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4f69d_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_4f69d_row3_col0" class="data row3 col0" >0.027919</td>
#       <td id="T_4f69d_row3_col1" class="data row3 col1" >0.032875</td>
#       <td id="T_4f69d_row3_col2" class="data row3 col2" >0.468750</td>
#       <td id="T_4f69d_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_4f69d_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_4f69d_row4_col0" class="data row4 col0" >0.034148</td>
#       <td id="T_4f69d_row4_col1" class="data row4 col1" >0.029211</td>
#       <td id="T_4f69d_row4_col2" class="data row4 col2" >0.396726</td>
#       <td id="T_4f69d_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_4f69d_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_4f69d_row5_col0" class="data row5 col0" >0.051515</td>
#       <td id="T_4f69d_row5_col1" class="data row5 col1" >0.046141</td>
#       <td id="T_4f69d_row5_col2" class="data row5 col2" >0.325392</td>
#       <td id="T_4f69d_row5_col3" class="data row5 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_4f69d_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_4f69d_row6_col0" class="data row6 col0" >0.045193</td>
#       <td id="T_4f69d_row6_col1" class="data row6 col1" >0.047298</td>
#       <td id="T_4f69d_row6_col2" class="data row6 col2" >0.963226</td>
#       <td id="T_4f69d_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_4f69d_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_4f69d_row7_col0" class="data row7 col0" >0.023873</td>
#       <td id="T_4f69d_row7_col1" class="data row7 col1" >0.019104</td>
#       <td id="T_4f69d_row7_col2" class="data row7 col2" >0.273322</td>
#       <td id="T_4f69d_row7_col3" class="data row7 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4f69d_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_4f69d_row8_col0" class="data row8 col0" >0.085653</td>
#       <td id="T_4f69d_row8_col1" class="data row8 col1" >0.107392</td>
#       <td id="T_4f69d_row8_col2" class="data row8 col2" >0.500000</td>
#       <td id="T_4f69d_row8_col3" class="data row8 col3" >2</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rouge2_recall and original_rouge2_recall:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# <style type="text/css">
# #T_74106 th {
#   text-align: center;
# }
# #T_74106_row0_col0, #T_74106_row0_col1, #T_74106_row0_col2, #T_74106_row0_col3, #T_74106_row1_col0, #T_74106_row1_col1, #T_74106_row1_col2, #T_74106_row1_col3, #T_74106_row2_col0, #T_74106_row2_col1, #T_74106_row2_col2, #T_74106_row2_col3, #T_74106_row3_col0, #T_74106_row3_col1, #T_74106_row3_col2, #T_74106_row3_col3, #T_74106_row4_col0, #T_74106_row4_col1, #T_74106_row4_col2, #T_74106_row4_col3, #T_74106_row5_col0, #T_74106_row5_col1, #T_74106_row5_col2, #T_74106_row5_col3, #T_74106_row6_col0, #T_74106_row6_col1, #T_74106_row6_col2, #T_74106_row6_col3, #T_74106_row7_col0, #T_74106_row7_col1, #T_74106_row7_col2, #T_74106_row7_col3, #T_74106_row8_col0, #T_74106_row8_col1, #T_74106_row8_col2, #T_74106_row8_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_74106" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74106_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge2_recall</th>
#       <th id="T_74106_level0_col1" class="col_heading level0 col1" >original_rouge2_recall</th>
#       <th id="T_74106_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_74106_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74106_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_74106_row0_col0" class="data row0 col0" >0.043169</td>
#       <td id="T_74106_row0_col1" class="data row0 col1" >0.037731</td>
#       <td id="T_74106_row0_col2" class="data row0 col2" >0.400418</td>
#       <td id="T_74106_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_74106_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_74106_row1_col0" class="data row1 col0" >0.032447</td>
#       <td id="T_74106_row1_col1" class="data row1 col1" >0.034336</td>
#       <td id="T_74106_row1_col2" class="data row1 col2" >0.986134</td>
#       <td id="T_74106_row1_col3" class="data row1 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_74106_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_74106_row2_col0" class="data row2 col0" >0.045355</td>
#       <td id="T_74106_row2_col1" class="data row2 col1" >0.024157</td>
#       <td id="T_74106_row2_col2" class="data row2 col2" >0.043114</td>
#       <td id="T_74106_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_74106_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_74106_row3_col0" class="data row3 col0" >0.015904</td>
#       <td id="T_74106_row3_col1" class="data row3 col1" >0.016484</td>
#       <td id="T_74106_row3_col2" class="data row3 col2" >0.812500</td>
#       <td id="T_74106_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_74106_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_74106_row4_col0" class="data row4 col0" >0.030506</td>
#       <td id="T_74106_row4_col1" class="data row4 col1" >0.025510</td>
#       <td id="T_74106_row4_col2" class="data row4 col2" >0.463071</td>
#       <td id="T_74106_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_74106_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_74106_row5_col0" class="data row5 col0" >0.042489</td>
#       <td id="T_74106_row5_col1" class="data row5 col1" >0.034509</td>
#       <td id="T_74106_row5_col2" class="data row5 col2" >0.074143</td>
#       <td id="T_74106_row5_col3" class="data row5 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_74106_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_74106_row6_col0" class="data row6 col0" >0.038431</td>
#       <td id="T_74106_row6_col1" class="data row6 col1" >0.041964</td>
#       <td id="T_74106_row6_col2" class="data row6 col2" >0.234321</td>
#       <td id="T_74106_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_74106_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_74106_row7_col0" class="data row7 col0" >0.019817</td>
#       <td id="T_74106_row7_col1" class="data row7 col1" >0.020949</td>
#       <td id="T_74106_row7_col2" class="data row7 col2" >0.654721</td>
#       <td id="T_74106_row7_col3" class="data row7 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_74106_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_74106_row8_col0" class="data row8 col0" >0.031761</td>
#       <td id="T_74106_row8_col1" class="data row8 col1" >0.038034</td>
#       <td id="T_74106_row8_col2" class="data row8 col2" >0.500000</td>
#       <td id="T_74106_row8_col3" class="data row8 col3" >2</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rouge2_fmeasure and original_rouge2_fmeasure:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# <style type="text/css">
# #T_c4b6f th {
#   text-align: center;
# }
# #T_c4b6f_row0_col0, #T_c4b6f_row0_col1, #T_c4b6f_row0_col2, #T_c4b6f_row0_col3, #T_c4b6f_row1_col0, #T_c4b6f_row1_col1, #T_c4b6f_row1_col2, #T_c4b6f_row1_col3, #T_c4b6f_row2_col0, #T_c4b6f_row2_col1, #T_c4b6f_row2_col2, #T_c4b6f_row2_col3, #T_c4b6f_row3_col0, #T_c4b6f_row3_col1, #T_c4b6f_row3_col2, #T_c4b6f_row3_col3, #T_c4b6f_row4_col0, #T_c4b6f_row4_col1, #T_c4b6f_row4_col2, #T_c4b6f_row4_col3, #T_c4b6f_row5_col0, #T_c4b6f_row5_col1, #T_c4b6f_row5_col2, #T_c4b6f_row5_col3, #T_c4b6f_row6_col0, #T_c4b6f_row6_col1, #T_c4b6f_row6_col2, #T_c4b6f_row6_col3, #T_c4b6f_row7_col0, #T_c4b6f_row7_col1, #T_c4b6f_row7_col2, #T_c4b6f_row7_col3, #T_c4b6f_row8_col0, #T_c4b6f_row8_col1, #T_c4b6f_row8_col2, #T_c4b6f_row8_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_c4b6f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4b6f_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge2_fmeasure</th>
#       <th id="T_c4b6f_level0_col1" class="col_heading level0 col1" >original_rouge2_fmeasure</th>
#       <th id="T_c4b6f_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_c4b6f_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4b6f_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_c4b6f_row0_col0" class="data row0 col0" >0.038844</td>
#       <td id="T_c4b6f_row0_col1" class="data row0 col1" >0.038210</td>
#       <td id="T_c4b6f_row0_col2" class="data row0 col2" >0.610589</td>
#       <td id="T_c4b6f_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_c4b6f_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_c4b6f_row1_col0" class="data row1 col0" >0.031309</td>
#       <td id="T_c4b6f_row1_col1" class="data row1 col1" >0.030959</td>
#       <td id="T_c4b6f_row1_col2" class="data row1 col2" >0.822184</td>
#       <td id="T_c4b6f_row1_col3" class="data row1 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_c4b6f_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_c4b6f_row2_col0" class="data row2 col0" >0.039953</td>
#       <td id="T_c4b6f_row2_col1" class="data row2 col1" >0.026015</td>
#       <td id="T_c4b6f_row2_col2" class="data row2 col2" >0.062500</td>
#       <td id="T_c4b6f_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c4b6f_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_c4b6f_row3_col0" class="data row3 col0" >0.017006</td>
#       <td id="T_c4b6f_row3_col1" class="data row3 col1" >0.018055</td>
#       <td id="T_c4b6f_row3_col2" class="data row3 col2" >0.812500</td>
#       <td id="T_c4b6f_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c4b6f_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_c4b6f_row4_col0" class="data row4 col0" >0.030313</td>
#       <td id="T_c4b6f_row4_col1" class="data row4 col1" >0.026041</td>
#       <td id="T_c4b6f_row4_col2" class="data row4 col2" >0.509797</td>
#       <td id="T_c4b6f_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_c4b6f_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_c4b6f_row5_col0" class="data row5 col0" >0.042349</td>
#       <td id="T_c4b6f_row5_col1" class="data row5 col1" >0.036174</td>
#       <td id="T_c4b6f_row5_col2" class="data row5 col2" >0.107315</td>
#       <td id="T_c4b6f_row5_col3" class="data row5 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c4b6f_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_c4b6f_row6_col0" class="data row6 col0" >0.040046</td>
#       <td id="T_c4b6f_row6_col1" class="data row6 col1" >0.042309</td>
#       <td id="T_c4b6f_row6_col2" class="data row6 col2" >0.579056</td>
#       <td id="T_c4b6f_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_c4b6f_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_c4b6f_row7_col0" class="data row7 col0" >0.021012</td>
#       <td id="T_c4b6f_row7_col1" class="data row7 col1" >0.018740</td>
#       <td id="T_c4b6f_row7_col2" class="data row7 col2" >0.715001</td>
#       <td id="T_c4b6f_row7_col3" class="data row7 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c4b6f_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_c4b6f_row8_col0" class="data row8 col0" >0.045173</td>
#       <td id="T_c4b6f_row8_col1" class="data row8 col1" >0.053784</td>
#       <td id="T_c4b6f_row8_col2" class="data row8 col2" >0.500000</td>
#       <td id="T_c4b6f_row8_col3" class="data row8 col3" >2</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rougeL_precision and original_rougeL_precision:
# <style type="text/css">
# #T_8d12b th {
#   text-align: center;
# }
# #T_8d12b_row0_col0, #T_8d12b_row0_col1, #T_8d12b_row0_col2, #T_8d12b_row0_col3, #T_8d12b_row1_col0, #T_8d12b_row1_col1, #T_8d12b_row1_col2, #T_8d12b_row1_col3, #T_8d12b_row2_col0, #T_8d12b_row2_col1, #T_8d12b_row2_col2, #T_8d12b_row2_col3, #T_8d12b_row3_col0, #T_8d12b_row3_col1, #T_8d12b_row3_col2, #T_8d12b_row3_col3, #T_8d12b_row4_col0, #T_8d12b_row4_col1, #T_8d12b_row4_col2, #T_8d12b_row4_col3, #T_8d12b_row5_col0, #T_8d12b_row5_col1, #T_8d12b_row5_col2, #T_8d12b_row5_col3, #T_8d12b_row6_col0, #T_8d12b_row6_col1, #T_8d12b_row6_col2, #T_8d12b_row6_col3, #T_8d12b_row7_col0, #T_8d12b_row7_col1, #T_8d12b_row7_col2, #T_8d12b_row7_col3, #T_8d12b_row8_col0, #T_8d12b_row8_col1, #T_8d12b_row8_col2, #T_8d12b_row8_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_8d12b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d12b_level0_col0" class="col_heading level0 col0" >fine-tuned_rougeL_precision</th>
#       <th id="T_8d12b_level0_col1" class="col_heading level0 col1" >original_rougeL_precision</th>
#       <th id="T_8d12b_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_8d12b_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d12b_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_8d12b_row0_col0" class="data row0 col0" >0.166440</td>
#       <td id="T_8d12b_row0_col1" class="data row0 col1" >0.167768</td>
#       <td id="T_8d12b_row0_col2" class="data row0 col2" >0.959630</td>
#       <td id="T_8d12b_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_8d12b_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_8d12b_row1_col0" class="data row1 col0" >0.150856</td>
#       <td id="T_8d12b_row1_col1" class="data row1 col1" >0.151364</td>
#       <td id="T_8d12b_row1_col2" class="data row1 col2" >0.802801</td>
#       <td id="T_8d12b_row1_col3" class="data row1 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_8d12b_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_8d12b_row2_col0" class="data row2 col0" >0.165679</td>
#       <td id="T_8d12b_row2_col1" class="data row2 col1" >0.188586</td>
#       <td id="T_8d12b_row2_col2" class="data row2 col2" >0.218750</td>
#       <td id="T_8d12b_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_8d12b_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_8d12b_row3_col0" class="data row3 col0" >0.171366</td>
#       <td id="T_8d12b_row3_col1" class="data row3 col1" >0.173521</td>
#       <td id="T_8d12b_row3_col2" class="data row3 col2" >0.937500</td>
#       <td id="T_8d12b_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_8d12b_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_8d12b_row4_col0" class="data row4 col0" >0.153139</td>
#       <td id="T_8d12b_row4_col1" class="data row4 col1" >0.165200</td>
#       <td id="T_8d12b_row4_col2" class="data row4 col2" >0.252380</td>
#       <td id="T_8d12b_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_8d12b_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_8d12b_row5_col0" class="data row5 col0" >0.173319</td>
#       <td id="T_8d12b_row5_col1" class="data row5 col1" >0.177899</td>
#       <td id="T_8d12b_row5_col2" class="data row5 col2" >0.287229</td>
#       <td id="T_8d12b_row5_col3" class="data row5 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8d12b_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_8d12b_row6_col0" class="data row6 col0" >0.175238</td>
#       <td id="T_8d12b_row6_col1" class="data row6 col1" >0.171918</td>
#       <td id="T_8d12b_row6_col2" class="data row6 col2" >0.547668</td>
#       <td id="T_8d12b_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_8d12b_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_8d12b_row7_col0" class="data row7 col0" >0.150877</td>
#       <td id="T_8d12b_row7_col1" class="data row7 col1" >0.162736</td>
#       <td id="T_8d12b_row7_col2" class="data row7 col2" >0.687500</td>
#       <td id="T_8d12b_row7_col3" class="data row7 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_8d12b_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_8d12b_row8_col0" class="data row8 col0" >0.241375</td>
#       <td id="T_8d12b_row8_col1" class="data row8 col1" >0.265025</td>
#       <td id="T_8d12b_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_8d12b_row8_col3" class="data row8 col3" >2</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rougeL_recall and original_rougeL_recall:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# <style type="text/css">
# #T_2ce0e th {
#   text-align: center;
# }
# #T_2ce0e_row0_col0, #T_2ce0e_row0_col1, #T_2ce0e_row0_col2, #T_2ce0e_row0_col3, #T_2ce0e_row1_col0, #T_2ce0e_row1_col1, #T_2ce0e_row1_col2, #T_2ce0e_row1_col3, #T_2ce0e_row2_col0, #T_2ce0e_row2_col1, #T_2ce0e_row2_col2, #T_2ce0e_row2_col3, #T_2ce0e_row3_col0, #T_2ce0e_row3_col1, #T_2ce0e_row3_col2, #T_2ce0e_row3_col3, #T_2ce0e_row4_col0, #T_2ce0e_row4_col1, #T_2ce0e_row4_col2, #T_2ce0e_row4_col3, #T_2ce0e_row5_col0, #T_2ce0e_row5_col1, #T_2ce0e_row5_col2, #T_2ce0e_row5_col3, #T_2ce0e_row6_col0, #T_2ce0e_row6_col1, #T_2ce0e_row6_col2, #T_2ce0e_row6_col3, #T_2ce0e_row7_col0, #T_2ce0e_row7_col1, #T_2ce0e_row7_col2, #T_2ce0e_row7_col3, #T_2ce0e_row8_col0, #T_2ce0e_row8_col1, #T_2ce0e_row8_col2, #T_2ce0e_row8_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_2ce0e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ce0e_level0_col0" class="col_heading level0 col0" >fine-tuned_rougeL_recall</th>
#       <th id="T_2ce0e_level0_col1" class="col_heading level0 col1" >original_rougeL_recall</th>
#       <th id="T_2ce0e_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_2ce0e_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ce0e_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_2ce0e_row0_col0" class="data row0 col0" >0.164493</td>
#       <td id="T_2ce0e_row0_col1" class="data row0 col1" >0.156542</td>
#       <td id="T_2ce0e_row0_col2" class="data row0 col2" >0.289477</td>
#       <td id="T_2ce0e_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_2ce0e_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_2ce0e_row1_col0" class="data row1 col0" >0.160944</td>
#       <td id="T_2ce0e_row1_col1" class="data row1 col1" >0.157517</td>
#       <td id="T_2ce0e_row1_col2" class="data row1 col2" >0.765198</td>
#       <td id="T_2ce0e_row1_col3" class="data row1 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_2ce0e_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_2ce0e_row2_col0" class="data row2 col0" >0.194810</td>
#       <td id="T_2ce0e_row2_col1" class="data row2 col1" >0.153710</td>
#       <td id="T_2ce0e_row2_col2" class="data row2 col2" >0.043114</td>
#       <td id="T_2ce0e_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2ce0e_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_2ce0e_row3_col0" class="data row3 col0" >0.134166</td>
#       <td id="T_2ce0e_row3_col1" class="data row3 col1" >0.143722</td>
#       <td id="T_2ce0e_row3_col2" class="data row3 col2" >0.465209</td>
#       <td id="T_2ce0e_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_2ce0e_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_2ce0e_row4_col0" class="data row4 col0" >0.146579</td>
#       <td id="T_2ce0e_row4_col1" class="data row4 col1" >0.147644</td>
#       <td id="T_2ce0e_row4_col2" class="data row4 col2" >0.972125</td>
#       <td id="T_2ce0e_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_2ce0e_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_2ce0e_row5_col0" class="data row5 col0" >0.151902</td>
#       <td id="T_2ce0e_row5_col1" class="data row5 col1" >0.143531</td>
#       <td id="T_2ce0e_row5_col2" class="data row5 col2" >0.088277</td>
#       <td id="T_2ce0e_row5_col3" class="data row5 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_2ce0e_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_2ce0e_row6_col0" class="data row6 col0" >0.154973</td>
#       <td id="T_2ce0e_row6_col1" class="data row6 col1" >0.163712</td>
#       <td id="T_2ce0e_row6_col2" class="data row6 col2" >0.432626</td>
#       <td id="T_2ce0e_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_2ce0e_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_2ce0e_row7_col0" class="data row7 col0" >0.136263</td>
#       <td id="T_2ce0e_row7_col1" class="data row7 col1" >0.132789</td>
#       <td id="T_2ce0e_row7_col2" class="data row7 col2" >0.685830</td>
#       <td id="T_2ce0e_row7_col3" class="data row7 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_2ce0e_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_2ce0e_row8_col0" class="data row8 col0" >0.106011</td>
#       <td id="T_2ce0e_row8_col1" class="data row8 col1" >0.109650</td>
#       <td id="T_2ce0e_row8_col2" class="data row8 col2" >0.500000</td>
#       <td id="T_2ce0e_row8_col3" class="data row8 col3" >2</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rougeL_fmeasure and original_rougeL_fmeasure:
# <style type="text/css">
# #T_b3668 th {
#   text-align: center;
# }
# #T_b3668_row0_col0, #T_b3668_row0_col1, #T_b3668_row0_col2, #T_b3668_row0_col3, #T_b3668_row1_col0, #T_b3668_row1_col1, #T_b3668_row1_col2, #T_b3668_row1_col3, #T_b3668_row2_col0, #T_b3668_row2_col1, #T_b3668_row2_col2, #T_b3668_row2_col3, #T_b3668_row3_col0, #T_b3668_row3_col1, #T_b3668_row3_col2, #T_b3668_row3_col3, #T_b3668_row4_col0, #T_b3668_row4_col1, #T_b3668_row4_col2, #T_b3668_row4_col3, #T_b3668_row5_col0, #T_b3668_row5_col1, #T_b3668_row5_col2, #T_b3668_row5_col3, #T_b3668_row6_col0, #T_b3668_row6_col1, #T_b3668_row6_col2, #T_b3668_row6_col3, #T_b3668_row7_col0, #T_b3668_row7_col1, #T_b3668_row7_col2, #T_b3668_row7_col3, #T_b3668_row8_col0, #T_b3668_row8_col1, #T_b3668_row8_col2, #T_b3668_row8_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_b3668" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3668_level0_col0" class="col_heading level0 col0" >fine-tuned_rougeL_fmeasure</th>
#       <th id="T_b3668_level0_col1" class="col_heading level0 col1" >original_rougeL_fmeasure</th>
#       <th id="T_b3668_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_b3668_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3668_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_b3668_row0_col0" class="data row0 col0" >0.150529</td>
#       <td id="T_b3668_row0_col1" class="data row0 col1" >0.145545</td>
#       <td id="T_b3668_row0_col2" class="data row0 col2" >0.101225</td>
#       <td id="T_b3668_row0_col3" class="data row0 col3" >34</td>
#     </tr>
#     <tr>
#       <th id="T_b3668_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_b3668_row1_col0" class="data row1 col0" >0.142142</td>
#       <td id="T_b3668_row1_col1" class="data row1 col1" >0.140890</td>
#       <td id="T_b3668_row1_col2" class="data row1 col2" >0.802801</td>
#       <td id="T_b3668_row1_col3" class="data row1 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_b3668_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_b3668_row2_col0" class="data row2 col0" >0.145090</td>
#       <td id="T_b3668_row2_col1" class="data row2 col1" >0.131433</td>
#       <td id="T_b3668_row2_col2" class="data row2 col2" >0.093750</td>
#       <td id="T_b3668_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b3668_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_b3668_row3_col0" class="data row3 col0" >0.131938</td>
#       <td id="T_b3668_row3_col1" class="data row3 col1" >0.137566</td>
#       <td id="T_b3668_row3_col2" class="data row3 col2" >0.812500</td>
#       <td id="T_b3668_row3_col3" class="data row3 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_b3668_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_b3668_row4_col0" class="data row4 col0" >0.135697</td>
#       <td id="T_b3668_row4_col1" class="data row4 col1" >0.142723</td>
#       <td id="T_b3668_row4_col2" class="data row4 col2" >0.229309</td>
#       <td id="T_b3668_row4_col3" class="data row4 col3" >15</td>
#     </tr>
#     <tr>
#       <th id="T_b3668_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_b3668_row5_col0" class="data row5 col0" >0.146823</td>
#       <td id="T_b3668_row5_col1" class="data row5 col1" >0.145740</td>
#       <td id="T_b3668_row5_col2" class="data row5 col2" >0.691519</td>
#       <td id="T_b3668_row5_col3" class="data row5 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b3668_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_b3668_row6_col0" class="data row6 col0" >0.156868</td>
#       <td id="T_b3668_row6_col1" class="data row6 col1" >0.158842</td>
#       <td id="T_b3668_row6_col2" class="data row6 col2" >0.889969</td>
#       <td id="T_b3668_row6_col3" class="data row6 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_b3668_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_b3668_row7_col0" class="data row7 col0" >0.133616</td>
#       <td id="T_b3668_row7_col1" class="data row7 col1" >0.124202</td>
#       <td id="T_b3668_row7_col2" class="data row7 col2" >0.437500</td>
#       <td id="T_b3668_row7_col3" class="data row7 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b3668_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_b3668_row8_col0" class="data row8 col0" >0.143166</td>
#       <td id="T_b3668_row8_col1" class="data row8 col1" >0.148087</td>
#       <td id="T_b3668_row8_col2" class="data row8 col2" >0.500000</td>
#       <td id="T_b3668_row8_col3" class="data row8 col3" >2</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------

# %% [markdown]
# ## LLM Evaluation with Topic Modeling

# %%
llm_eval = pd.read_csv('phi3-qlora/llm_eval.csv')
llm_eval.head()
# Out:
#    acorreal/phi3-mental-health  microsoft/Phi-3-mini-4k-instruct
# 0                          7.5                               7.5
# 1                          8.5                               7.5
# 2                          7.5                               7.5
# 3                          7.5                               7.5
# 4                          8.5                               7.5

# %%
llm_eval['topic'] = topic_names

# %%
llm_eval.head()
# Out:
#    acorreal/phi3-mental-health  microsoft/Phi-3-mini-4k-instruct  \
# 0                          7.5                               7.5
# 1                          8.5                               7.5
# 2                          7.5                               7.5
# 3                          7.5                               7.5
# 4                          8.5                               7.5
#
#                     topic
# 0  Romantic Relationships
# 1  Romantic Relationships
# 2              Parenthood
# 3         People Feelings
# 4       Counseling Issues

# %%
# getting the tipics in the dataset
topics = llm_eval['topic'].unique()
topics
# Out:
# array(['Romantic Relationships', 'Parenthood', 'People Feelings',
#        'Counseling Issues', 'Other', 'Anxiety and Depression',
#        'Negative Thoughts', 'Therapy and Therapist', 'Work-Life Balance'],
#       dtype=object)

# %%
def statistical_test(data, topics):
  result = []
  for topic in topics:
    data_t = data.loc[data['topic'] == topic]
    data1 = data_t['acorreal/phi3-mental-health']
    data2 = data_t['microsoft/Phi-3-mini-4k-instruct']
    try:
      _, p_value = wilcoxon(data1, data2)
    except Exception as e:
      p_value = np.nan
      print(f"Error processing topic '{topic}': {e}")
    result.append((topic, p_value))
  return result

# %%
results = statistical_test(llm_eval, topics)
# Out:
# Error processing topic 'Work-Life Balance': zero_method 'wilcox' and 'pratt' do not work if x - y is zero for all elements.
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %%
results
# Out:
# [('Romantic Relationships', 0.7388826803635273),
#  ('Parenthood', 0.31731050786291415),
#  ('People Feelings', 0.17971249487899976),
#  ('Counseling Issues', nan),
#  ('Other', 0.6547208460185769),
#  ('Anxiety and Depression', 0.8515548977976366),
#  ('Negative Thoughts', 0.6547208460185769),
#  ('Therapy and Therapist', 0.4142161782425252),
#  ('Work-Life Balance', nan)]

# %%
llm_t_test = llm_eval.groupby('topic').mean()

# %%
llm_t_test['p_value'] = 0.0
for result in results:
  llm_t_test.loc[result[0], 'p_value'] = result[1]

# %%
llm_t_test.style.set_properties(**{'text-align': 'center'}).set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'center')]}]
)
# Out:
# <style type="text/css">
# #T_33e0a th {
#   text-align: center;
# }
# #T_33e0a_row0_col0, #T_33e0a_row0_col1, #T_33e0a_row0_col2, #T_33e0a_row1_col0, #T_33e0a_row1_col1, #T_33e0a_row1_col2, #T_33e0a_row2_col0, #T_33e0a_row2_col1, #T_33e0a_row2_col2, #T_33e0a_row3_col0, #T_33e0a_row3_col1, #T_33e0a_row3_col2, #T_33e0a_row4_col0, #T_33e0a_row4_col1, #T_33e0a_row4_col2, #T_33e0a_row5_col0, #T_33e0a_row5_col1, #T_33e0a_row5_col2, #T_33e0a_row6_col0, #T_33e0a_row6_col1, #T_33e0a_row6_col2, #T_33e0a_row7_col0, #T_33e0a_row7_col1, #T_33e0a_row7_col2, #T_33e0a_row8_col0, #T_33e0a_row8_col1, #T_33e0a_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_33e0a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33e0a_level0_col0" class="col_heading level0 col0" >acorreal/phi3-mental-health</th>
#       <th id="T_33e0a_level0_col1" class="col_heading level0 col1" >microsoft/Phi-3-mini-4k-instruct</th>
#       <th id="T_33e0a_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33e0a_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_33e0a_row0_col0" class="data row0 col0" >7.575758</td>
#       <td id="T_33e0a_row0_col1" class="data row0 col1" >7.696970</td>
#       <td id="T_33e0a_row0_col2" class="data row0 col2" >0.851555</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_33e0a_row1_col0" class="data row1 col0" >7.777778</td>
#       <td id="T_33e0a_row1_col1" class="data row1 col1" >7.730769</td>
#       <td id="T_33e0a_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_33e0a_row2_col0" class="data row2 col0" >7.833333</td>
#       <td id="T_33e0a_row2_col1" class="data row2 col1" >6.583333</td>
#       <td id="T_33e0a_row2_col2" class="data row2 col2" >0.654721</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_33e0a_row3_col0" class="data row3 col0" >6.428571</td>
#       <td id="T_33e0a_row3_col1" class="data row3 col1" >7.142857</td>
#       <td id="T_33e0a_row3_col2" class="data row3 col2" >0.654721</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_33e0a_row4_col0" class="data row4 col0" >7.633333</td>
#       <td id="T_33e0a_row4_col1" class="data row4 col1" >7.566667</td>
#       <td id="T_33e0a_row4_col2" class="data row4 col2" >0.317311</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_33e0a_row5_col0" class="data row5 col0" >7.700000</td>
#       <td id="T_33e0a_row5_col1" class="data row5 col1" >7.560000</td>
#       <td id="T_33e0a_row5_col2" class="data row5 col2" >0.179712</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_33e0a_row6_col0" class="data row6 col0" >7.529412</td>
#       <td id="T_33e0a_row6_col1" class="data row6 col1" >7.617647</td>
#       <td id="T_33e0a_row6_col2" class="data row6 col2" >0.738883</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_33e0a_row7_col0" class="data row7 col0" >7.833333</td>
#       <td id="T_33e0a_row7_col1" class="data row7 col1" >6.583333</td>
#       <td id="T_33e0a_row7_col2" class="data row7 col2" >0.414216</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_33e0a_row8_col0" class="data row8 col0" >7.500000</td>
#       <td id="T_33e0a_row8_col1" class="data row8 col1" >7.500000</td>
#       <td id="T_33e0a_row8_col2" class="data row8 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>
