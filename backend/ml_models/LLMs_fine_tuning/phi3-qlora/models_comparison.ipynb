# %% [markdown]
# # Comparing Models Performance

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.4)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=5a6488e07d926b2b09b2713b9a208b8f700e0a9e1cc13e897836475ae58603bb
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %% [markdown]
# ## Importing modules

# %%
# Get the scripts from remote source
# !git clone https://github.com/mlgomez0/Health_Therapist
# !mv Health_Therapist/backend/ml_models/modules .
# !mv Health_Therapist/backend/ml_models/datasets .
# !mv Health_Therapist/backend/ml_models/LLMs_fine_tuning/phi3-qlora .
# !mv Health_Therapist/requirements.txt .
# !rm -rf Health_Therapist
# Out:
# Cloning into 'Health_Therapist'...
# remote: Enumerating objects: 636, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 636 (delta 10), reused 6 (delta 1), pack-reused 585
# Receiving objects: 100% (636/636), 22.28 MiB | 13.35 MiB/s, done.
# Resolving deltas: 100% (252/252), done.

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import NMF
from sklearn.pipeline import Pipeline
import numpy as np
from scipy import stats
from scipy.stats import wilcoxon

# %%
fine_tuned_phi3_model_responses = pd.read_csv('phi3-qlora/model_responses.csv', index_col=False)
original_phi3_model_responses = pd.read_csv('phi3-qlora/original_model_responses.csv', index_col=False)

# %%
fine_tuned_phi3_model_responses.head()
# Out:
#    Unnamed: 0                                              input  \
# 0           0  i want a secure relationship with someone that...
# 1           1  my boyfriend is in recovery from drug addictio...
# 2           2  is this something i should be worried about sh...
# 3           3  my friend is abusing her prescription medicine...
# 4           4  i terminated my counseling relationship with a...
#
#                                               output  \
# 0  It sounds like you're going through a really t...
# 1  I'm truly sorry to hear that you're going thro...
# 2  I'm really glad you're reaching out and sharin...
# 3  I'm really sorry to hear that you're going thr...
# 4  I'm really glad to hear that you're considerin...
#
#                                     therapist_output
# 0  good for you on your keen awareness of your di...
# 1  my empathy goes out to you relationships are t...
# 2  it can be tricky to figure out if a child is t...
# 3  first of all where did you find the pills did ...
# 4  yes your former social worker should return yo...

# %% [markdown]
# ## Topic Modeling

# %%
text = fine_tuned_phi3_model_responses['input'] + ' ' + fine_tuned_phi3_model_responses['therapist_output']

# %%
df = pd.read_csv('datasets/dataset.csv')

# %%
vectorizer = CountVectorizer(min_df=10, max_df=0.5, stop_words="english") # To transform the text into a numerical representation
topic_model = NMF(n_components=10)

topic_pipeline = Pipeline(
    [
        ("vectorizer", vectorizer),
        ("topic_model", topic_model),
    ]
)

# %%
topic_pipeline.fit(text)
# Out:
# Pipeline(steps=[('vectorizer',
#                  CountVectorizer(max_df=0.5, min_df=10, stop_words='english')),
#                 ('topic_model', NMF(n_components=10))])

# %%
# dictionary to map the topics

topics_map = {
    0: "Work-Life Balance",
    1: "Other",
    2: "Romantic Relationships",
    3: "Therapy and Therapist",
    4: "Negative Thoughts",
    5: "Parenthood",
    6: "People Feelings",
    7: "Anxiety and Depression",
    8: "Anxiety and Depression",
    9: "Counseling Issues"
}

# %%
topics = topic_pipeline.transform(text)
topics = np.argmax(topics, axis=1)
topic_names = [topics_map[topic] for topic in topics]

# %% [markdown]
# ## Rouge Score with Topic Modeling

# %%
from modules.model_tester import ModelTester

# %%
rouge_tester_fine_tuned = ModelTester(fine_tuned_phi3_model_responses['therapist_output'], fine_tuned_phi3_model_responses['output'])
rouge_tester_original = ModelTester(original_phi3_model_responses['therapist_output'], original_phi3_model_responses['output'])

# %%
rouge_scores_fine_tuned = rouge_tester_fine_tuned.calculate_rouge_score_by_item()
rouge_scores_original = rouge_tester_original.calculate_rouge_score_by_item()

# %%
len(rouge_scores_fine_tuned['rouge1']['precision'])
# Out:
# 138

# %%
rouge_df = pd.DataFrame()

# %%
for key in rouge_scores_fine_tuned.keys():
  for val in rouge_scores_fine_tuned[key].keys():
    fine_tuned_model_name = "fine-tuned_" + key + "_" + val
    original_model_name = "original_" + key + "_" + val
    rouge_df[fine_tuned_model_name] = rouge_scores_fine_tuned[key][val]
    rouge_df[original_model_name] = rouge_scores_original[key][val]

rouge_df['topic'] = topic_names
rouge_df.head()
# Out:
#    fine-tuned_rouge1_precision  original_rouge1_precision  \
# 0                     0.336066                   0.295337
# 1                     0.445087                   0.455696
# 2                     0.506667                   0.465517
# 3                     0.521739                   0.542169
# 4                     0.172973                   0.169312
#
#    fine-tuned_rouge1_recall  original_rouge1_recall  \
# 0                  0.312977                0.435115
# 1                  0.375610                0.351220
# 2                  0.102981                0.073171
# 3                  0.186047                0.174419
# 4                  0.367816                0.367816
#
#    fine-tuned_rouge1_fmeasure  original_rouge1_fmeasure  \
# 0                    0.324111                  0.351852
# 1                    0.407407                  0.396694
# 2                    0.171171                  0.126464
# 3                    0.274286                  0.263930
# 4                    0.235294                  0.231884
#
#    fine-tuned_rouge2_precision  original_rouge2_precision  \
# 0                     0.033058                   0.026042
# 1                     0.046512                   0.044586
# 2                     0.027027                   0.000000
# 3                     0.032967                   0.048780
# 4                     0.010870                   0.026596
#
#    fine-tuned_rouge2_recall  original_rouge2_recall  \
# 0                  0.030769                0.038462
# 1                  0.039216                0.034314
# 2                  0.005435                0.000000
# 3                  0.011673                0.015564
# 4                  0.023256                0.058140
#
#    fine-tuned_rouge2_fmeasure  original_rouge2_fmeasure  \
# 0                    0.031873                  0.031056
# 1                    0.042553                  0.038781
# 2                    0.009050                  0.000000
# 3                    0.017241                  0.023599
# 4                    0.014815                  0.036496
#
#    fine-tuned_rougeL_precision  original_rougeL_precision  \
# 0                     0.180328                   0.155440
# 1                     0.179191                   0.170886
# 2                     0.253333                   0.241379
# 3                     0.260870                   0.301205
# 4                     0.086486                   0.111111
#
#    fine-tuned_rougeL_recall  original_rougeL_recall  \
# 0                  0.167939                0.229008
# 1                  0.151220                0.131707
# 2                  0.051491                0.037940
# 3                  0.093023                0.096899
# 4                  0.183908                0.241379
#
#    fine-tuned_rougeL_fmeasure  original_rougeL_fmeasure  \
# 0                    0.173913                  0.185185
# 1                    0.164021                  0.148760
# 2                    0.085586                  0.065574
# 3                    0.137143                  0.146628
# 4                    0.117647                  0.152174
#
#                     topic
# 0  Romantic Relationships
# 1  Romantic Relationships
# 2              Parenthood
# 3         People Feelings
# 4       Counseling Issues

# %%
topics = rouge_df['topic'].unique()
topics
# Out:
# array(['Romantic Relationships', 'Parenthood', 'People Feelings',
#        'Counseling Issues', 'Other', 'Anxiety and Depression',
#        'Negative Thoughts', 'Therapy and Therapist', 'Work-Life Balance'],
#       dtype=object)

# %%
def statistical_test_rouge(data, topics, col1, col2):
  result = []
  for topic in topics:
    data_t = data.loc[data['topic'] == topic]
    data1 = data_t[col1]
    data2 = data_t[col2]
    data1 = data1.dropna()
    data2 = data2.dropna()
    _, p_value = wilcoxon(data1, data2)
    result.append((topic, p_value))
  return result

# %%
def get_rouge_scores_df(data, topics, col1, col2):
  rouge_ttest = statistical_test_rouge(data, topics, col1, col2)
  df_result = data[['topic', col1, col2]].groupby('topic').mean()
  df_result['p_value'] = 0.0
  for result in rouge_ttest:
    df_result.loc[result[0], 'p_value'] = result[1]
  return df_result

# %%
from IPython.display import display

# %%
cols = rouge_df.columns
for i in range(0, len(cols) - 1, 2):
  partial_rouge_df = get_rouge_scores_df(rouge_df, topics, cols[i], cols[i + 1])
  print(f"ROUGE scores between {cols[i]} and {cols[i + 1]}:")
  display(partial_rouge_df.style.set_properties(**{'text-align': 'center'}).set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'center')]}]
  ))
  print("\n" + "-"*80 + "\n")
# Out:
# ROUGE scores between fine-tuned_rouge1_precision and original_rouge1_precision:
# <style type="text/css">
# #T_17e7d th {
#   text-align: center;
# }
# #T_17e7d_row0_col0, #T_17e7d_row0_col1, #T_17e7d_row0_col2, #T_17e7d_row1_col0, #T_17e7d_row1_col1, #T_17e7d_row1_col2, #T_17e7d_row2_col0, #T_17e7d_row2_col1, #T_17e7d_row2_col2, #T_17e7d_row3_col0, #T_17e7d_row3_col1, #T_17e7d_row3_col2, #T_17e7d_row4_col0, #T_17e7d_row4_col1, #T_17e7d_row4_col2, #T_17e7d_row5_col0, #T_17e7d_row5_col1, #T_17e7d_row5_col2, #T_17e7d_row6_col0, #T_17e7d_row6_col1, #T_17e7d_row6_col2, #T_17e7d_row7_col0, #T_17e7d_row7_col1, #T_17e7d_row7_col2, #T_17e7d_row8_col0, #T_17e7d_row8_col1, #T_17e7d_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_17e7d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17e7d_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge1_precision</th>
#       <th id="T_17e7d_level0_col1" class="col_heading level0 col1" >original_rouge1_precision</th>
#       <th id="T_17e7d_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17e7d_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_17e7d_row0_col0" class="data row0 col0" >0.339819</td>
#       <td id="T_17e7d_row0_col1" class="data row0 col1" >0.343043</td>
#       <td id="T_17e7d_row0_col2" class="data row0 col2" >0.684959</td>
#     </tr>
#     <tr>
#       <th id="T_17e7d_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_17e7d_row1_col0" class="data row1 col0" >0.312045</td>
#       <td id="T_17e7d_row1_col1" class="data row1 col1" >0.314652</td>
#       <td id="T_17e7d_row1_col2" class="data row1 col2" >0.627664</td>
#     </tr>
#     <tr>
#       <th id="T_17e7d_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_17e7d_row2_col0" class="data row2 col0" >0.342085</td>
#       <td id="T_17e7d_row2_col1" class="data row2 col1" >0.367882</td>
#       <td id="T_17e7d_row2_col2" class="data row2 col2" >0.218750</td>
#     </tr>
#     <tr>
#       <th id="T_17e7d_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_17e7d_row3_col0" class="data row3 col0" >0.369295</td>
#       <td id="T_17e7d_row3_col1" class="data row3 col1" >0.331799</td>
#       <td id="T_17e7d_row3_col2" class="data row3 col2" >0.015625</td>
#     </tr>
#     <tr>
#       <th id="T_17e7d_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_17e7d_row4_col0" class="data row4 col0" >0.320798</td>
#       <td id="T_17e7d_row4_col1" class="data row4 col1" >0.335238</td>
#       <td id="T_17e7d_row4_col2" class="data row4 col2" >0.803955</td>
#     </tr>
#     <tr>
#       <th id="T_17e7d_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_17e7d_row5_col0" class="data row5 col0" >0.372615</td>
#       <td id="T_17e7d_row5_col1" class="data row5 col1" >0.379737</td>
#       <td id="T_17e7d_row5_col2" class="data row5 col2" >0.578206</td>
#     </tr>
#     <tr>
#       <th id="T_17e7d_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_17e7d_row6_col0" class="data row6 col0" >0.375831</td>
#       <td id="T_17e7d_row6_col1" class="data row6 col1" >0.360225</td>
#       <td id="T_17e7d_row6_col2" class="data row6 col2" >0.088654</td>
#     </tr>
#     <tr>
#       <th id="T_17e7d_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_17e7d_row7_col0" class="data row7 col0" >0.301859</td>
#       <td id="T_17e7d_row7_col1" class="data row7 col1" >0.293430</td>
#       <td id="T_17e7d_row7_col2" class="data row7 col2" >0.687500</td>
#     </tr>
#     <tr>
#       <th id="T_17e7d_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_17e7d_row8_col0" class="data row8 col0" >0.513283</td>
#       <td id="T_17e7d_row8_col1" class="data row8 col1" >0.538579</td>
#       <td id="T_17e7d_row8_col2" class="data row8 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rouge1_recall and original_rouge1_recall:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# <style type="text/css">
# #T_72fd3 th {
#   text-align: center;
# }
# #T_72fd3_row0_col0, #T_72fd3_row0_col1, #T_72fd3_row0_col2, #T_72fd3_row1_col0, #T_72fd3_row1_col1, #T_72fd3_row1_col2, #T_72fd3_row2_col0, #T_72fd3_row2_col1, #T_72fd3_row2_col2, #T_72fd3_row3_col0, #T_72fd3_row3_col1, #T_72fd3_row3_col2, #T_72fd3_row4_col0, #T_72fd3_row4_col1, #T_72fd3_row4_col2, #T_72fd3_row5_col0, #T_72fd3_row5_col1, #T_72fd3_row5_col2, #T_72fd3_row6_col0, #T_72fd3_row6_col1, #T_72fd3_row6_col2, #T_72fd3_row7_col0, #T_72fd3_row7_col1, #T_72fd3_row7_col2, #T_72fd3_row8_col0, #T_72fd3_row8_col1, #T_72fd3_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_72fd3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72fd3_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge1_recall</th>
#       <th id="T_72fd3_level0_col1" class="col_heading level0 col1" >original_rouge1_recall</th>
#       <th id="T_72fd3_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72fd3_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_72fd3_row0_col0" class="data row0 col0" >0.327049</td>
#       <td id="T_72fd3_row0_col1" class="data row0 col1" >0.319658</td>
#       <td id="T_72fd3_row0_col2" class="data row0 col2" >0.596490</td>
#     </tr>
#     <tr>
#       <th id="T_72fd3_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_72fd3_row1_col0" class="data row1 col0" >0.313498</td>
#       <td id="T_72fd3_row1_col1" class="data row1 col1" >0.307272</td>
#       <td id="T_72fd3_row1_col2" class="data row1 col2" >0.967806</td>
#     </tr>
#     <tr>
#       <th id="T_72fd3_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_72fd3_row2_col0" class="data row2 col0" >0.368321</td>
#       <td id="T_72fd3_row2_col1" class="data row2 col1" >0.292958</td>
#       <td id="T_72fd3_row2_col2" class="data row2 col2" >0.031250</td>
#     </tr>
#     <tr>
#       <th id="T_72fd3_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_72fd3_row3_col0" class="data row3 col0" >0.293831</td>
#       <td id="T_72fd3_row3_col1" class="data row3 col1" >0.272240</td>
#       <td id="T_72fd3_row3_col2" class="data row3 col2" >0.296875</td>
#     </tr>
#     <tr>
#       <th id="T_72fd3_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_72fd3_row4_col0" class="data row4 col0" >0.298963</td>
#       <td id="T_72fd3_row4_col1" class="data row4 col1" >0.288357</td>
#       <td id="T_72fd3_row4_col2" class="data row4 col2" >0.388186</td>
#     </tr>
#     <tr>
#       <th id="T_72fd3_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_72fd3_row5_col0" class="data row5 col0" >0.313644</td>
#       <td id="T_72fd3_row5_col1" class="data row5 col1" >0.296986</td>
#       <td id="T_72fd3_row5_col2" class="data row5 col2" >0.172959</td>
#     </tr>
#     <tr>
#       <th id="T_72fd3_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_72fd3_row6_col0" class="data row6 col0" >0.330195</td>
#       <td id="T_72fd3_row6_col1" class="data row6 col1" >0.336992</td>
#       <td id="T_72fd3_row6_col2" class="data row6 col2" >0.679116</td>
#     </tr>
#     <tr>
#       <th id="T_72fd3_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_72fd3_row7_col0" class="data row7 col0" >0.272494</td>
#       <td id="T_72fd3_row7_col1" class="data row7 col1" >0.250529</td>
#       <td id="T_72fd3_row7_col2" class="data row7 col2" >0.562500</td>
#     </tr>
#     <tr>
#       <th id="T_72fd3_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_72fd3_row8_col0" class="data row8 col0" >0.218200</td>
#       <td id="T_72fd3_row8_col1" class="data row8 col1" >0.218232</td>
#       <td id="T_72fd3_row8_col2" class="data row8 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rouge1_fmeasure and original_rouge1_fmeasure:
# <style type="text/css">
# #T_5eac5 th {
#   text-align: center;
# }
# #T_5eac5_row0_col0, #T_5eac5_row0_col1, #T_5eac5_row0_col2, #T_5eac5_row1_col0, #T_5eac5_row1_col1, #T_5eac5_row1_col2, #T_5eac5_row2_col0, #T_5eac5_row2_col1, #T_5eac5_row2_col2, #T_5eac5_row3_col0, #T_5eac5_row3_col1, #T_5eac5_row3_col2, #T_5eac5_row4_col0, #T_5eac5_row4_col1, #T_5eac5_row4_col2, #T_5eac5_row5_col0, #T_5eac5_row5_col1, #T_5eac5_row5_col2, #T_5eac5_row6_col0, #T_5eac5_row6_col1, #T_5eac5_row6_col2, #T_5eac5_row7_col0, #T_5eac5_row7_col1, #T_5eac5_row7_col2, #T_5eac5_row8_col0, #T_5eac5_row8_col1, #T_5eac5_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_5eac5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5eac5_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge1_fmeasure</th>
#       <th id="T_5eac5_level0_col1" class="col_heading level0 col1" >original_rouge1_fmeasure</th>
#       <th id="T_5eac5_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5eac5_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_5eac5_row0_col0" class="data row0 col0" >0.308211</td>
#       <td id="T_5eac5_row0_col1" class="data row0 col1" >0.302272</td>
#       <td id="T_5eac5_row0_col2" class="data row0 col2" >0.426360</td>
#     </tr>
#     <tr>
#       <th id="T_5eac5_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_5eac5_row1_col0" class="data row1 col0" >0.284504</td>
#       <td id="T_5eac5_row1_col1" class="data row1 col1" >0.283091</td>
#       <td id="T_5eac5_row1_col2" class="data row1 col2" >0.785742</td>
#     </tr>
#     <tr>
#       <th id="T_5eac5_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_5eac5_row2_col0" class="data row2 col0" >0.290141</td>
#       <td id="T_5eac5_row2_col1" class="data row2 col1" >0.252528</td>
#       <td id="T_5eac5_row2_col2" class="data row2 col2" >0.156250</td>
#     </tr>
#     <tr>
#       <th id="T_5eac5_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_5eac5_row3_col0" class="data row3 col0" >0.289533</td>
#       <td id="T_5eac5_row3_col1" class="data row3 col1" >0.264760</td>
#       <td id="T_5eac5_row3_col2" class="data row3 col2" >0.218750</td>
#     </tr>
#     <tr>
#       <th id="T_5eac5_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_5eac5_row4_col0" class="data row4 col0" >0.282395</td>
#       <td id="T_5eac5_row4_col1" class="data row4 col1" >0.286328</td>
#       <td id="T_5eac5_row4_col2" class="data row4 col2" >0.977966</td>
#     </tr>
#     <tr>
#       <th id="T_5eac5_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_5eac5_row5_col0" class="data row5 col0" >0.309963</td>
#       <td id="T_5eac5_row5_col1" class="data row5 col1" >0.306974</td>
#       <td id="T_5eac5_row5_col2" class="data row5 col2" >0.490786</td>
#     </tr>
#     <tr>
#       <th id="T_5eac5_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_5eac5_row6_col0" class="data row6 col0" >0.335375</td>
#       <td id="T_5eac5_row6_col1" class="data row6 col1" >0.330825</td>
#       <td id="T_5eac5_row6_col2" class="data row6 col2" >0.611221</td>
#     </tr>
#     <tr>
#       <th id="T_5eac5_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_5eac5_row7_col0" class="data row7 col0" >0.266584</td>
#       <td id="T_5eac5_row7_col1" class="data row7 col1" >0.230650</td>
#       <td id="T_5eac5_row7_col2" class="data row7 col2" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_5eac5_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_5eac5_row8_col0" class="data row8 col0" >0.297508</td>
#       <td id="T_5eac5_row8_col1" class="data row8 col1" >0.296488</td>
#       <td id="T_5eac5_row8_col2" class="data row8 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rouge2_precision and original_rouge2_precision:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# <style type="text/css">
# #T_a4d68 th {
#   text-align: center;
# }
# #T_a4d68_row0_col0, #T_a4d68_row0_col1, #T_a4d68_row0_col2, #T_a4d68_row1_col0, #T_a4d68_row1_col1, #T_a4d68_row1_col2, #T_a4d68_row2_col0, #T_a4d68_row2_col1, #T_a4d68_row2_col2, #T_a4d68_row3_col0, #T_a4d68_row3_col1, #T_a4d68_row3_col2, #T_a4d68_row4_col0, #T_a4d68_row4_col1, #T_a4d68_row4_col2, #T_a4d68_row5_col0, #T_a4d68_row5_col1, #T_a4d68_row5_col2, #T_a4d68_row6_col0, #T_a4d68_row6_col1, #T_a4d68_row6_col2, #T_a4d68_row7_col0, #T_a4d68_row7_col1, #T_a4d68_row7_col2, #T_a4d68_row8_col0, #T_a4d68_row8_col1, #T_a4d68_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_a4d68" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4d68_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge2_precision</th>
#       <th id="T_a4d68_level0_col1" class="col_heading level0 col1" >original_rouge2_precision</th>
#       <th id="T_a4d68_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4d68_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_a4d68_row0_col0" class="data row0 col0" >0.040794</td>
#       <td id="T_a4d68_row0_col1" class="data row0 col1" >0.041687</td>
#       <td id="T_a4d68_row0_col2" class="data row0 col2" >0.985081</td>
#     </tr>
#     <tr>
#       <th id="T_a4d68_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_a4d68_row1_col0" class="data row1 col0" >0.037802</td>
#       <td id="T_a4d68_row1_col1" class="data row1 col1" >0.037204</td>
#       <td id="T_a4d68_row1_col2" class="data row1 col2" >0.896588</td>
#     </tr>
#     <tr>
#       <th id="T_a4d68_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_a4d68_row2_col0" class="data row2 col0" >0.055203</td>
#       <td id="T_a4d68_row2_col1" class="data row2 col1" >0.045224</td>
#       <td id="T_a4d68_row2_col2" class="data row2 col2" >0.156250</td>
#     </tr>
#     <tr>
#       <th id="T_a4d68_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_a4d68_row3_col0" class="data row3 col0" >0.027919</td>
#       <td id="T_a4d68_row3_col1" class="data row3 col1" >0.032875</td>
#       <td id="T_a4d68_row3_col2" class="data row3 col2" >0.468750</td>
#     </tr>
#     <tr>
#       <th id="T_a4d68_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_a4d68_row4_col0" class="data row4 col0" >0.034148</td>
#       <td id="T_a4d68_row4_col1" class="data row4 col1" >0.029211</td>
#       <td id="T_a4d68_row4_col2" class="data row4 col2" >0.396726</td>
#     </tr>
#     <tr>
#       <th id="T_a4d68_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_a4d68_row5_col0" class="data row5 col0" >0.051515</td>
#       <td id="T_a4d68_row5_col1" class="data row5 col1" >0.046141</td>
#       <td id="T_a4d68_row5_col2" class="data row5 col2" >0.325392</td>
#     </tr>
#     <tr>
#       <th id="T_a4d68_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_a4d68_row6_col0" class="data row6 col0" >0.045193</td>
#       <td id="T_a4d68_row6_col1" class="data row6 col1" >0.047298</td>
#       <td id="T_a4d68_row6_col2" class="data row6 col2" >0.963226</td>
#     </tr>
#     <tr>
#       <th id="T_a4d68_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_a4d68_row7_col0" class="data row7 col0" >0.023873</td>
#       <td id="T_a4d68_row7_col1" class="data row7 col1" >0.019104</td>
#       <td id="T_a4d68_row7_col2" class="data row7 col2" >0.273322</td>
#     </tr>
#     <tr>
#       <th id="T_a4d68_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_a4d68_row8_col0" class="data row8 col0" >0.085653</td>
#       <td id="T_a4d68_row8_col1" class="data row8 col1" >0.107392</td>
#       <td id="T_a4d68_row8_col2" class="data row8 col2" >0.500000</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rouge2_recall and original_rouge2_recall:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# <style type="text/css">
# #T_0c06f th {
#   text-align: center;
# }
# #T_0c06f_row0_col0, #T_0c06f_row0_col1, #T_0c06f_row0_col2, #T_0c06f_row1_col0, #T_0c06f_row1_col1, #T_0c06f_row1_col2, #T_0c06f_row2_col0, #T_0c06f_row2_col1, #T_0c06f_row2_col2, #T_0c06f_row3_col0, #T_0c06f_row3_col1, #T_0c06f_row3_col2, #T_0c06f_row4_col0, #T_0c06f_row4_col1, #T_0c06f_row4_col2, #T_0c06f_row5_col0, #T_0c06f_row5_col1, #T_0c06f_row5_col2, #T_0c06f_row6_col0, #T_0c06f_row6_col1, #T_0c06f_row6_col2, #T_0c06f_row7_col0, #T_0c06f_row7_col1, #T_0c06f_row7_col2, #T_0c06f_row8_col0, #T_0c06f_row8_col1, #T_0c06f_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_0c06f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c06f_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge2_recall</th>
#       <th id="T_0c06f_level0_col1" class="col_heading level0 col1" >original_rouge2_recall</th>
#       <th id="T_0c06f_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c06f_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_0c06f_row0_col0" class="data row0 col0" >0.043338</td>
#       <td id="T_0c06f_row0_col1" class="data row0 col1" >0.037622</td>
#       <td id="T_0c06f_row0_col2" class="data row0 col2" >0.394863</td>
#     </tr>
#     <tr>
#       <th id="T_0c06f_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_0c06f_row1_col0" class="data row1 col0" >0.032638</td>
#       <td id="T_0c06f_row1_col1" class="data row1 col1" >0.034596</td>
#       <td id="T_0c06f_row1_col2" class="data row1 col2" >0.961160</td>
#     </tr>
#     <tr>
#       <th id="T_0c06f_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_0c06f_row2_col0" class="data row2 col0" >0.045355</td>
#       <td id="T_0c06f_row2_col1" class="data row2 col1" >0.024157</td>
#       <td id="T_0c06f_row2_col2" class="data row2 col2" >0.043114</td>
#     </tr>
#     <tr>
#       <th id="T_0c06f_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_0c06f_row3_col0" class="data row3 col0" >0.015904</td>
#       <td id="T_0c06f_row3_col1" class="data row3 col1" >0.016484</td>
#       <td id="T_0c06f_row3_col2" class="data row3 col2" >0.812500</td>
#     </tr>
#     <tr>
#       <th id="T_0c06f_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_0c06f_row4_col0" class="data row4 col0" >0.030506</td>
#       <td id="T_0c06f_row4_col1" class="data row4 col1" >0.025510</td>
#       <td id="T_0c06f_row4_col2" class="data row4 col2" >0.463071</td>
#     </tr>
#     <tr>
#       <th id="T_0c06f_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_0c06f_row5_col0" class="data row5 col0" >0.042489</td>
#       <td id="T_0c06f_row5_col1" class="data row5 col1" >0.034509</td>
#       <td id="T_0c06f_row5_col2" class="data row5 col2" >0.074143</td>
#     </tr>
#     <tr>
#       <th id="T_0c06f_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_0c06f_row6_col0" class="data row6 col0" >0.038431</td>
#       <td id="T_0c06f_row6_col1" class="data row6 col1" >0.041964</td>
#       <td id="T_0c06f_row6_col2" class="data row6 col2" >0.234321</td>
#     </tr>
#     <tr>
#       <th id="T_0c06f_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_0c06f_row7_col0" class="data row7 col0" >0.019817</td>
#       <td id="T_0c06f_row7_col1" class="data row7 col1" >0.020949</td>
#       <td id="T_0c06f_row7_col2" class="data row7 col2" >0.654721</td>
#     </tr>
#     <tr>
#       <th id="T_0c06f_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_0c06f_row8_col0" class="data row8 col0" >0.031761</td>
#       <td id="T_0c06f_row8_col1" class="data row8 col1" >0.038034</td>
#       <td id="T_0c06f_row8_col2" class="data row8 col2" >0.500000</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rouge2_fmeasure and original_rouge2_fmeasure:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# <style type="text/css">
# #T_2a3f5 th {
#   text-align: center;
# }
# #T_2a3f5_row0_col0, #T_2a3f5_row0_col1, #T_2a3f5_row0_col2, #T_2a3f5_row1_col0, #T_2a3f5_row1_col1, #T_2a3f5_row1_col2, #T_2a3f5_row2_col0, #T_2a3f5_row2_col1, #T_2a3f5_row2_col2, #T_2a3f5_row3_col0, #T_2a3f5_row3_col1, #T_2a3f5_row3_col2, #T_2a3f5_row4_col0, #T_2a3f5_row4_col1, #T_2a3f5_row4_col2, #T_2a3f5_row5_col0, #T_2a3f5_row5_col1, #T_2a3f5_row5_col2, #T_2a3f5_row6_col0, #T_2a3f5_row6_col1, #T_2a3f5_row6_col2, #T_2a3f5_row7_col0, #T_2a3f5_row7_col1, #T_2a3f5_row7_col2, #T_2a3f5_row8_col0, #T_2a3f5_row8_col1, #T_2a3f5_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_2a3f5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a3f5_level0_col0" class="col_heading level0 col0" >fine-tuned_rouge2_fmeasure</th>
#       <th id="T_2a3f5_level0_col1" class="col_heading level0 col1" >original_rouge2_fmeasure</th>
#       <th id="T_2a3f5_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a3f5_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_2a3f5_row0_col0" class="data row0 col0" >0.038401</td>
#       <td id="T_2a3f5_row0_col1" class="data row0 col1" >0.037590</td>
#       <td id="T_2a3f5_row0_col2" class="data row0 col2" >0.562139</td>
#     </tr>
#     <tr>
#       <th id="T_2a3f5_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_2a3f5_row1_col0" class="data row1 col0" >0.032130</td>
#       <td id="T_2a3f5_row1_col1" class="data row1 col1" >0.031985</td>
#       <td id="T_2a3f5_row1_col2" class="data row1 col2" >0.859313</td>
#     </tr>
#     <tr>
#       <th id="T_2a3f5_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_2a3f5_row2_col0" class="data row2 col0" >0.039953</td>
#       <td id="T_2a3f5_row2_col1" class="data row2 col1" >0.026015</td>
#       <td id="T_2a3f5_row2_col2" class="data row2 col2" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_2a3f5_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_2a3f5_row3_col0" class="data row3 col0" >0.017006</td>
#       <td id="T_2a3f5_row3_col1" class="data row3 col1" >0.018055</td>
#       <td id="T_2a3f5_row3_col2" class="data row3 col2" >0.812500</td>
#     </tr>
#     <tr>
#       <th id="T_2a3f5_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_2a3f5_row4_col0" class="data row4 col0" >0.030313</td>
#       <td id="T_2a3f5_row4_col1" class="data row4 col1" >0.026041</td>
#       <td id="T_2a3f5_row4_col2" class="data row4 col2" >0.509797</td>
#     </tr>
#     <tr>
#       <th id="T_2a3f5_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_2a3f5_row5_col0" class="data row5 col0" >0.042349</td>
#       <td id="T_2a3f5_row5_col1" class="data row5 col1" >0.036174</td>
#       <td id="T_2a3f5_row5_col2" class="data row5 col2" >0.107315</td>
#     </tr>
#     <tr>
#       <th id="T_2a3f5_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_2a3f5_row6_col0" class="data row6 col0" >0.040046</td>
#       <td id="T_2a3f5_row6_col1" class="data row6 col1" >0.042309</td>
#       <td id="T_2a3f5_row6_col2" class="data row6 col2" >0.579056</td>
#     </tr>
#     <tr>
#       <th id="T_2a3f5_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_2a3f5_row7_col0" class="data row7 col0" >0.021012</td>
#       <td id="T_2a3f5_row7_col1" class="data row7 col1" >0.018740</td>
#       <td id="T_2a3f5_row7_col2" class="data row7 col2" >0.715001</td>
#     </tr>
#     <tr>
#       <th id="T_2a3f5_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_2a3f5_row8_col0" class="data row8 col0" >0.045173</td>
#       <td id="T_2a3f5_row8_col1" class="data row8 col1" >0.053784</td>
#       <td id="T_2a3f5_row8_col2" class="data row8 col2" >0.500000</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rougeL_precision and original_rougeL_precision:
# <style type="text/css">
# #T_c72a8 th {
#   text-align: center;
# }
# #T_c72a8_row0_col0, #T_c72a8_row0_col1, #T_c72a8_row0_col2, #T_c72a8_row1_col0, #T_c72a8_row1_col1, #T_c72a8_row1_col2, #T_c72a8_row2_col0, #T_c72a8_row2_col1, #T_c72a8_row2_col2, #T_c72a8_row3_col0, #T_c72a8_row3_col1, #T_c72a8_row3_col2, #T_c72a8_row4_col0, #T_c72a8_row4_col1, #T_c72a8_row4_col2, #T_c72a8_row5_col0, #T_c72a8_row5_col1, #T_c72a8_row5_col2, #T_c72a8_row6_col0, #T_c72a8_row6_col1, #T_c72a8_row6_col2, #T_c72a8_row7_col0, #T_c72a8_row7_col1, #T_c72a8_row7_col2, #T_c72a8_row8_col0, #T_c72a8_row8_col1, #T_c72a8_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_c72a8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c72a8_level0_col0" class="col_heading level0 col0" >fine-tuned_rougeL_precision</th>
#       <th id="T_c72a8_level0_col1" class="col_heading level0 col1" >original_rougeL_precision</th>
#       <th id="T_c72a8_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c72a8_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_c72a8_row0_col0" class="data row0 col0" >0.163700</td>
#       <td id="T_c72a8_row0_col1" class="data row0 col1" >0.165965</td>
#       <td id="T_c72a8_row0_col2" class="data row0 col2" >0.832451</td>
#     </tr>
#     <tr>
#       <th id="T_c72a8_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_c72a8_row1_col0" class="data row1 col0" >0.154783</td>
#       <td id="T_c72a8_row1_col1" class="data row1 col1" >0.154176</td>
#       <td id="T_c72a8_row1_col2" class="data row1 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c72a8_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_c72a8_row2_col0" class="data row2 col0" >0.165679</td>
#       <td id="T_c72a8_row2_col1" class="data row2 col1" >0.188586</td>
#       <td id="T_c72a8_row2_col2" class="data row2 col2" >0.218750</td>
#     </tr>
#     <tr>
#       <th id="T_c72a8_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_c72a8_row3_col0" class="data row3 col0" >0.171366</td>
#       <td id="T_c72a8_row3_col1" class="data row3 col1" >0.173521</td>
#       <td id="T_c72a8_row3_col2" class="data row3 col2" >0.937500</td>
#     </tr>
#     <tr>
#       <th id="T_c72a8_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_c72a8_row4_col0" class="data row4 col0" >0.153139</td>
#       <td id="T_c72a8_row4_col1" class="data row4 col1" >0.165200</td>
#       <td id="T_c72a8_row4_col2" class="data row4 col2" >0.252380</td>
#     </tr>
#     <tr>
#       <th id="T_c72a8_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_c72a8_row5_col0" class="data row5 col0" >0.173319</td>
#       <td id="T_c72a8_row5_col1" class="data row5 col1" >0.177899</td>
#       <td id="T_c72a8_row5_col2" class="data row5 col2" >0.287229</td>
#     </tr>
#     <tr>
#       <th id="T_c72a8_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_c72a8_row6_col0" class="data row6 col0" >0.175238</td>
#       <td id="T_c72a8_row6_col1" class="data row6 col1" >0.171918</td>
#       <td id="T_c72a8_row6_col2" class="data row6 col2" >0.547668</td>
#     </tr>
#     <tr>
#       <th id="T_c72a8_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_c72a8_row7_col0" class="data row7 col0" >0.150877</td>
#       <td id="T_c72a8_row7_col1" class="data row7 col1" >0.162736</td>
#       <td id="T_c72a8_row7_col2" class="data row7 col2" >0.687500</td>
#     </tr>
#     <tr>
#       <th id="T_c72a8_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_c72a8_row8_col0" class="data row8 col0" >0.241375</td>
#       <td id="T_c72a8_row8_col1" class="data row8 col1" >0.265025</td>
#       <td id="T_c72a8_row8_col2" class="data row8 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rougeL_recall and original_rougeL_recall:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# <style type="text/css">
# #T_d08ff th {
#   text-align: center;
# }
# #T_d08ff_row0_col0, #T_d08ff_row0_col1, #T_d08ff_row0_col2, #T_d08ff_row1_col0, #T_d08ff_row1_col1, #T_d08ff_row1_col2, #T_d08ff_row2_col0, #T_d08ff_row2_col1, #T_d08ff_row2_col2, #T_d08ff_row3_col0, #T_d08ff_row3_col1, #T_d08ff_row3_col2, #T_d08ff_row4_col0, #T_d08ff_row4_col1, #T_d08ff_row4_col2, #T_d08ff_row5_col0, #T_d08ff_row5_col1, #T_d08ff_row5_col2, #T_d08ff_row6_col0, #T_d08ff_row6_col1, #T_d08ff_row6_col2, #T_d08ff_row7_col0, #T_d08ff_row7_col1, #T_d08ff_row7_col2, #T_d08ff_row8_col0, #T_d08ff_row8_col1, #T_d08ff_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_d08ff" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d08ff_level0_col0" class="col_heading level0 col0" >fine-tuned_rougeL_recall</th>
#       <th id="T_d08ff_level0_col1" class="col_heading level0 col1" >original_rougeL_recall</th>
#       <th id="T_d08ff_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d08ff_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_d08ff_row0_col0" class="data row0 col0" >0.166300</td>
#       <td id="T_d08ff_row0_col1" class="data row0 col1" >0.158449</td>
#       <td id="T_d08ff_row0_col2" class="data row0 col2" >0.325186</td>
#     </tr>
#     <tr>
#       <th id="T_d08ff_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_d08ff_row1_col0" class="data row1 col0" >0.158867</td>
#       <td id="T_d08ff_row1_col1" class="data row1 col1" >0.155151</td>
#       <td id="T_d08ff_row1_col2" class="data row1 col2" >0.715145</td>
#     </tr>
#     <tr>
#       <th id="T_d08ff_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_d08ff_row2_col0" class="data row2 col0" >0.194810</td>
#       <td id="T_d08ff_row2_col1" class="data row2 col1" >0.153710</td>
#       <td id="T_d08ff_row2_col2" class="data row2 col2" >0.043114</td>
#     </tr>
#     <tr>
#       <th id="T_d08ff_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_d08ff_row3_col0" class="data row3 col0" >0.134166</td>
#       <td id="T_d08ff_row3_col1" class="data row3 col1" >0.143722</td>
#       <td id="T_d08ff_row3_col2" class="data row3 col2" >0.465209</td>
#     </tr>
#     <tr>
#       <th id="T_d08ff_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_d08ff_row4_col0" class="data row4 col0" >0.146579</td>
#       <td id="T_d08ff_row4_col1" class="data row4 col1" >0.147644</td>
#       <td id="T_d08ff_row4_col2" class="data row4 col2" >0.972125</td>
#     </tr>
#     <tr>
#       <th id="T_d08ff_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_d08ff_row5_col0" class="data row5 col0" >0.151902</td>
#       <td id="T_d08ff_row5_col1" class="data row5 col1" >0.143531</td>
#       <td id="T_d08ff_row5_col2" class="data row5 col2" >0.088277</td>
#     </tr>
#     <tr>
#       <th id="T_d08ff_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_d08ff_row6_col0" class="data row6 col0" >0.154973</td>
#       <td id="T_d08ff_row6_col1" class="data row6 col1" >0.163712</td>
#       <td id="T_d08ff_row6_col2" class="data row6 col2" >0.432626</td>
#     </tr>
#     <tr>
#       <th id="T_d08ff_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_d08ff_row7_col0" class="data row7 col0" >0.136263</td>
#       <td id="T_d08ff_row7_col1" class="data row7 col1" >0.132789</td>
#       <td id="T_d08ff_row7_col2" class="data row7 col2" >0.685830</td>
#     </tr>
#     <tr>
#       <th id="T_d08ff_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_d08ff_row8_col0" class="data row8 col0" >0.106011</td>
#       <td id="T_d08ff_row8_col1" class="data row8 col1" >0.109650</td>
#       <td id="T_d08ff_row8_col2" class="data row8 col2" >0.500000</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
#
# ROUGE scores between fine-tuned_rougeL_fmeasure and original_rougeL_fmeasure:
# <style type="text/css">
# #T_7716b th {
#   text-align: center;
# }
# #T_7716b_row0_col0, #T_7716b_row0_col1, #T_7716b_row0_col2, #T_7716b_row1_col0, #T_7716b_row1_col1, #T_7716b_row1_col2, #T_7716b_row2_col0, #T_7716b_row2_col1, #T_7716b_row2_col2, #T_7716b_row3_col0, #T_7716b_row3_col1, #T_7716b_row3_col2, #T_7716b_row4_col0, #T_7716b_row4_col1, #T_7716b_row4_col2, #T_7716b_row5_col0, #T_7716b_row5_col1, #T_7716b_row5_col2, #T_7716b_row6_col0, #T_7716b_row6_col1, #T_7716b_row6_col2, #T_7716b_row7_col0, #T_7716b_row7_col1, #T_7716b_row7_col2, #T_7716b_row8_col0, #T_7716b_row8_col1, #T_7716b_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_7716b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7716b_level0_col0" class="col_heading level0 col0" >fine-tuned_rougeL_fmeasure</th>
#       <th id="T_7716b_level0_col1" class="col_heading level0 col1" >original_rougeL_fmeasure</th>
#       <th id="T_7716b_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7716b_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_7716b_row0_col0" class="data row0 col0" >0.150577</td>
#       <td id="T_7716b_row0_col1" class="data row0 col1" >0.145936</td>
#       <td id="T_7716b_row0_col2" class="data row0 col2" >0.134750</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_7716b_row1_col0" class="data row1 col0" >0.142394</td>
#       <td id="T_7716b_row1_col1" class="data row1 col1" >0.140584</td>
#       <td id="T_7716b_row1_col2" class="data row1 col2" >0.661680</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_7716b_row2_col0" class="data row2 col0" >0.145090</td>
#       <td id="T_7716b_row2_col1" class="data row2 col1" >0.131433</td>
#       <td id="T_7716b_row2_col2" class="data row2 col2" >0.093750</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_7716b_row3_col0" class="data row3 col0" >0.131938</td>
#       <td id="T_7716b_row3_col1" class="data row3 col1" >0.137566</td>
#       <td id="T_7716b_row3_col2" class="data row3 col2" >0.812500</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_7716b_row4_col0" class="data row4 col0" >0.135697</td>
#       <td id="T_7716b_row4_col1" class="data row4 col1" >0.142723</td>
#       <td id="T_7716b_row4_col2" class="data row4 col2" >0.229309</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_7716b_row5_col0" class="data row5 col0" >0.146823</td>
#       <td id="T_7716b_row5_col1" class="data row5 col1" >0.145740</td>
#       <td id="T_7716b_row5_col2" class="data row5 col2" >0.691519</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_7716b_row6_col0" class="data row6 col0" >0.156868</td>
#       <td id="T_7716b_row6_col1" class="data row6 col1" >0.158842</td>
#       <td id="T_7716b_row6_col2" class="data row6 col2" >0.889969</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_7716b_row7_col0" class="data row7 col0" >0.133616</td>
#       <td id="T_7716b_row7_col1" class="data row7 col1" >0.124202</td>
#       <td id="T_7716b_row7_col2" class="data row7 col2" >0.437500</td>
#     </tr>
#     <tr>
#       <th id="T_7716b_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_7716b_row8_col0" class="data row8 col0" >0.143166</td>
#       <td id="T_7716b_row8_col1" class="data row8 col1" >0.148087</td>
#       <td id="T_7716b_row8_col2" class="data row8 col2" >0.500000</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------

# %% [markdown]
# ## LLM Evaluation with Topic Modeling

# %%
llm_eval = pd.read_csv('phi3-qlora/llm_eval.csv')
llm_eval.head()
# Out:
#    acorreal/phi3-mental-health  microsoft/Phi-3-mini-4k-instruct
# 0                          7.5                               7.5
# 1                          8.5                               7.5
# 2                          7.5                               7.5
# 3                          7.5                               7.5
# 4                          8.5                               7.5

# %%
llm_eval['topic'] = topic_names

# %%
llm_eval.head()
# Out:
#    acorreal/phi3-mental-health  microsoft/Phi-3-mini-4k-instruct  \
# 0                          7.5                               7.5
# 1                          8.5                               7.5
# 2                          7.5                               7.5
# 3                          7.5                               7.5
# 4                          8.5                               7.5
#
#                     topic
# 0  Romantic Relationships
# 1  Romantic Relationships
# 2              Parenthood
# 3         People Feelings
# 4       Counseling Issues

# %%
# getting the tipics in the dataset
topics = llm_eval['topic'].unique()
topics
# Out:
# array(['Romantic Relationships', 'Parenthood', 'People Feelings',
#        'Counseling Issues', 'Other', 'Anxiety and Depression',
#        'Negative Thoughts', 'Therapy and Therapist', 'Work-Life Balance'],
#       dtype=object)

# %%
def statistical_test(data, topics):
  result = []
  for topic in topics:
    data_t = data.loc[data['topic'] == topic]
    data1 = data_t['acorreal/phi3-mental-health']
    data2 = data_t['microsoft/Phi-3-mini-4k-instruct']
    try:
      _, p_value = wilcoxon(data1, data2)
    except Exception as e:
      p_value = np.nan
      print(f"Error processing topic '{topic}': {e}")
    result.append((topic, p_value))
  return result

# %%
results = statistical_test(llm_eval, topics)
# Out:
# Error processing topic 'Work-Life Balance': zero_method 'wilcox' and 'pratt' do not work if x - y is zero for all elements.
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %%
results
# Out:
# [('Romantic Relationships', 0.7388826803635273),
#  ('Parenthood', 0.31731050786291415),
#  ('People Feelings', 0.17971249487899976),
#  ('Counseling Issues', nan),
#  ('Other', 0.6547208460185769),
#  ('Anxiety and Depression', 0.8515548977976366),
#  ('Negative Thoughts', 0.6547208460185769),
#  ('Therapy and Therapist', 0.4142161782425252),
#  ('Work-Life Balance', nan)]

# %%
llm_t_test = llm_eval.groupby('topic').mean()

# %%
llm_t_test['p_value'] = 0.0
for result in results:
  llm_t_test.loc[result[0], 'p_value'] = result[1]

# %%
llm_t_test.style.set_properties(**{'text-align': 'center'}).set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'center')]}]
)
# Out:
# <style type="text/css">
# #T_33e0a th {
#   text-align: center;
# }
# #T_33e0a_row0_col0, #T_33e0a_row0_col1, #T_33e0a_row0_col2, #T_33e0a_row1_col0, #T_33e0a_row1_col1, #T_33e0a_row1_col2, #T_33e0a_row2_col0, #T_33e0a_row2_col1, #T_33e0a_row2_col2, #T_33e0a_row3_col0, #T_33e0a_row3_col1, #T_33e0a_row3_col2, #T_33e0a_row4_col0, #T_33e0a_row4_col1, #T_33e0a_row4_col2, #T_33e0a_row5_col0, #T_33e0a_row5_col1, #T_33e0a_row5_col2, #T_33e0a_row6_col0, #T_33e0a_row6_col1, #T_33e0a_row6_col2, #T_33e0a_row7_col0, #T_33e0a_row7_col1, #T_33e0a_row7_col2, #T_33e0a_row8_col0, #T_33e0a_row8_col1, #T_33e0a_row8_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_33e0a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33e0a_level0_col0" class="col_heading level0 col0" >acorreal/phi3-mental-health</th>
#       <th id="T_33e0a_level0_col1" class="col_heading level0 col1" >microsoft/Phi-3-mini-4k-instruct</th>
#       <th id="T_33e0a_level0_col2" class="col_heading level0 col2" >p_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33e0a_level0_row0" class="row_heading level0 row0" >Anxiety and Depression</th>
#       <td id="T_33e0a_row0_col0" class="data row0 col0" >7.575758</td>
#       <td id="T_33e0a_row0_col1" class="data row0 col1" >7.696970</td>
#       <td id="T_33e0a_row0_col2" class="data row0 col2" >0.851555</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row1" class="row_heading level0 row1" >Counseling Issues</th>
#       <td id="T_33e0a_row1_col0" class="data row1 col0" >7.777778</td>
#       <td id="T_33e0a_row1_col1" class="data row1 col1" >7.730769</td>
#       <td id="T_33e0a_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row2" class="row_heading level0 row2" >Negative Thoughts</th>
#       <td id="T_33e0a_row2_col0" class="data row2 col0" >7.833333</td>
#       <td id="T_33e0a_row2_col1" class="data row2 col1" >6.583333</td>
#       <td id="T_33e0a_row2_col2" class="data row2 col2" >0.654721</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_33e0a_row3_col0" class="data row3 col0" >6.428571</td>
#       <td id="T_33e0a_row3_col1" class="data row3 col1" >7.142857</td>
#       <td id="T_33e0a_row3_col2" class="data row3 col2" >0.654721</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row4" class="row_heading level0 row4" >Parenthood</th>
#       <td id="T_33e0a_row4_col0" class="data row4 col0" >7.633333</td>
#       <td id="T_33e0a_row4_col1" class="data row4 col1" >7.566667</td>
#       <td id="T_33e0a_row4_col2" class="data row4 col2" >0.317311</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row5" class="row_heading level0 row5" >People Feelings</th>
#       <td id="T_33e0a_row5_col0" class="data row5 col0" >7.700000</td>
#       <td id="T_33e0a_row5_col1" class="data row5 col1" >7.560000</td>
#       <td id="T_33e0a_row5_col2" class="data row5 col2" >0.179712</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row6" class="row_heading level0 row6" >Romantic Relationships</th>
#       <td id="T_33e0a_row6_col0" class="data row6 col0" >7.529412</td>
#       <td id="T_33e0a_row6_col1" class="data row6 col1" >7.617647</td>
#       <td id="T_33e0a_row6_col2" class="data row6 col2" >0.738883</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row7" class="row_heading level0 row7" >Therapy and Therapist</th>
#       <td id="T_33e0a_row7_col0" class="data row7 col0" >7.833333</td>
#       <td id="T_33e0a_row7_col1" class="data row7 col1" >6.583333</td>
#       <td id="T_33e0a_row7_col2" class="data row7 col2" >0.414216</td>
#     </tr>
#     <tr>
#       <th id="T_33e0a_level0_row8" class="row_heading level0 row8" >Work-Life Balance</th>
#       <td id="T_33e0a_row8_col0" class="data row8 col0" >7.500000</td>
#       <td id="T_33e0a_row8_col1" class="data row8 col1" >7.500000</td>
#       <td id="T_33e0a_row8_col2" class="data row8 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>
